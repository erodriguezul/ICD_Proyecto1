# %% [markdown]
# # Proyecto 1 - Introducción a Data Science

# %% [markdown]
# ### Cargaremos las librerías requiridas

# %%
import pandas as pd
import pandasql
import datetime
import numpy as np
import load_data
import clean_data
import transform_data
import eda

# %% [markdown]
# ## Importación de datos

# %% [markdown]
# Importaremos los datos con la función leedatos.

# %%
datos = load_data.leedatos("interrupcion-legal-del-embarazo.csv")

# %%
datos.head()
# Out:
#     AÑO     MES  CVE_HOSPITAL  FINGRESO        AUTOREF EDOCIVIL_DESCRIPCION  \
# 0  2016   Enero            10  12/01/16  AUTORREFERIDA              soltera
# 1  2016   Abril             1  25/04/16             no          unión libre
# 2  2018   Julio             4  11/07/18            NaN              soltera
# 3  2016   Enero            10  07/01/16  AUTORREFERIDA               casada
# 4  2018  Agosto             7       NaN             no          unión libre
#
#    EDAD DESC_DERECHOHAB              NIVEL_EDU  \
# 0    34         ninguna      primaria completa
# 1    27         ninguna  licenciatura completa
# 2    29         ninguna    secundaria completa
# 3    33         ninguna  preparatoria completa
# 4    23             N/E  preparatoria completa
#
#                         OCUPACION  ... C_NUM                  MOTILES  \
# 0                     Desempleada  ...   2.0  interrupción voluntaria
# 1                          Mesera  ...   NaN  interrupción voluntaria
# 2  Trabajadora del Sector Público  ...   2.0  interrupción voluntaria
# 3                     Ama de Casa  ...   2.0  interrupción voluntaria
# 4                             NaN  ...   2.0  interrupción voluntaria
#
#   H_FINGRESO       DESC_SERVICIO  P_SEMGEST  P_DIASGESTA P_CONSENT  \
# 0         NE  Salud Reproductiva        0.0          NaN        Si
# 1   25/04/16                 ILE       11.0          2.0        Si
# 2         NE                 ILE        7.0          6.0       NaN
# 3         NE  Salud Reproductiva        4.0          NaN        Si
# 4   24/08/18  Gineco Obstetrícia        7.0          3.0       NaN
#
#                                      PROCILE  S_COMPLICA          PANTICONCEP
# 0                                Misoprostol          Si                  NaN
# 1                                 Aspiración          No               condón
# 2  Mifepristona 200 mg + Misoprostol 800 mcg         NaN  Anticonceptivo Oral
# 3                                Misoprostol          Si                  NaN
# 4                                Misoprostol         NaN  implante subdermico
#
# [5 rows x 36 columns]

# %% [markdown]
# ## Limpieza de datos

# %% [markdown]
# Formatearemos los encabezados de las columnas de nuestro DataFrame con la función clean_column_headers.
#
# + Cambiaremos espacios por guion bajo
# + Quitaremos acentos, puntos y comas
# + Cambiaremos la letra ñ por ni

# %%
datos_format = clean_data.clean_column_headers(datos)
datos_format.head()
# Out:
#    anio     mes  cve_hospital  fingreso        autoref edocivil_descripcion  \
# 0  2016   Enero            10  12/01/16  AUTORREFERIDA              soltera
# 1  2016   Abril             1  25/04/16             no          unión libre
# 2  2018   Julio             4  11/07/18            NaN              soltera
# 3  2016   Enero            10  07/01/16  AUTORREFERIDA               casada
# 4  2018  Agosto             7       NaN             no          unión libre
#
#    edad desc_derechohab              nivel_edu  \
# 0    34         ninguna      primaria completa
# 1    27         ninguna  licenciatura completa
# 2    29         ninguna    secundaria completa
# 3    33         ninguna  preparatoria completa
# 4    23             N/E  preparatoria completa
#
#                         ocupacion  ... c_num                  motiles  \
# 0                     Desempleada  ...   2.0  interrupción voluntaria
# 1                          Mesera  ...   NaN  interrupción voluntaria
# 2  Trabajadora del Sector Público  ...   2.0  interrupción voluntaria
# 3                     Ama de Casa  ...   2.0  interrupción voluntaria
# 4                             NaN  ...   2.0  interrupción voluntaria
#
#   h_fingreso       desc_servicio  p_semgest  p_diasgesta p_consent  \
# 0         NE  Salud Reproductiva        0.0          NaN        Si
# 1   25/04/16                 ILE       11.0          2.0        Si
# 2         NE                 ILE        7.0          6.0       NaN
# 3         NE  Salud Reproductiva        4.0          NaN        Si
# 4   24/08/18  Gineco Obstetrícia        7.0          3.0       NaN
#
#                                      procile  s_complica          panticoncep
# 0                                Misoprostol          Si                  NaN
# 1                                 Aspiración          No               condón
# 2  Mifepristona 200 mg + Misoprostol 800 mcg         NaN  Anticonceptivo Oral
# 3                                Misoprostol          Si                  NaN
# 4                                Misoprostol         NaN  implante subdermico
#
# [5 rows x 36 columns]

# %% [markdown]
# ## Transformación de datos

# %% [markdown]
# Garantizaremos que los valores en blanco sean considerados como nulos.

# %%
datos_format = transform_data.nulos(datos_format)

# %% [markdown]
# Verificaremos que cada columna tenga el tipo correcto.

# %%
datos_format.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62003 entries, 0 to 62002
# Data columns (total 36 columns):
# anio                    62003 non-null int64
# mes                     62003 non-null object
# cve_hospital            62003 non-null int64
# fingreso                60420 non-null object
# autoref                 16874 non-null object
# edocivil_descripcion    61887 non-null object
# edad                    62003 non-null int64
# desc_derechohab         54962 non-null object
# nivel_edu               60719 non-null object
# ocupacion               54282 non-null object
# religion                60183 non-null object
# parentesco              20163 non-null object
# entidad                 61983 non-null object
# alc_o_municipio         57910 non-null object
# menarca                 59114 non-null float64
# fsexual                 57750 non-null float64
# fmenstrua               55299 non-null object
# sememb                  58403 non-null float64
# nhijos                  58794 non-null float64
# gesta                   59341 non-null float64
# naborto                 57888 non-null float64
# npartos                 58240 non-null float64
# ncesarea                57904 non-null float64
# nile                    49598 non-null float64
# consejeria              60047 non-null object
# anticonceptivo          55297 non-null object
# c_num                   41725 non-null float64
# motiles                 60915 non-null object
# h_fingreso              54466 non-null object
# desc_servicio           57788 non-null object
# p_semgest               61974 non-null float64
# p_diasgesta             48602 non-null float64
# p_consent               17856 non-null object
# procile                 60290 non-null object
# s_complica              32768 non-null object
# panticoncep             45199 non-null object
# dtypes: float64(12), int64(3), object(21)
# memory usage: 17.0+ MB

# %% [markdown]
# Despues de analizar el tipo de cada una de las variables contra su descripción, haremos los siguientes cambios:
#
# + fingreso - *object* a *date*
# + fmenstrua - *object* a *date*
# + h_fingreso - *object* a *date*

# %% [markdown]
# Empezaremos por la variable fingreso.

# %% [markdown]
# Haremos una consulta de los primeros registros unicos de la variable fingreso para ver que formato de fecha tiene.

# %%
sql = "SELECT DISTINCT fingreso FROM datos_format \
        LIMIT 5"
query = pandasql.sqldf(sql, globals())
query
# Out:
#    fingreso
# 0  12/01/16
# 1  25/04/16
# 2  11/07/18
# 3  07/01/16
# 4      None

# %% [markdown]
# El formato de la fecha es %d/%m%/%y, utilizaremos la función de pandas para especificar el formato y cambiar la fecha.

# %%
datos_format['fingreso'] = pd.to_datetime(datos_format['fingreso'], format='%d/%m/%y')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py in _convert_listlike_datetimes(arg, box, format, name, tz, unit, errors, infer_datetime_format, dayfirst, yearfirst, exact)
#     290             try:
# --> 291                 values, tz = conversion.datetime_to_datetime64(arg)
#     292                 return DatetimeIndex._simple_new(values, name=name, tz=tz)
#
# pandas/_libs/tslibs/conversion.pyx in pandas._libs.tslibs.conversion.datetime_to_datetime64()
#
# TypeError: Unrecognized value type: <class 'str'>
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-30b77db42e07> in <module>
# ----> 1 datos_format['fingreso'] = pd.to_datetime(datos_format['fingreso'], format='%d/%m/%y')
#
# ~\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py in to_datetime(arg, errors, dayfirst, yearfirst, utc, box, format, exact, unit, infer_datetime_format, origin, cache)
#     590         else:
#     591             from pandas import Series
# --> 592             values = convert_listlike(arg._values, True, format)
#     593             result = Series(values, index=arg.index, name=arg.name)
#     594     elif isinstance(arg, (ABCDataFrame, compat.MutableMapping)):
#
# ~\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py in _convert_listlike_datetimes(arg, box, format, name, tz, unit, errors, infer_datetime_format, dayfirst, yearfirst, exact)
#     292                 return DatetimeIndex._simple_new(values, name=name, tz=tz)
#     293             except (ValueError, TypeError):
# --> 294                 raise e
#     295
#     296     if result is None:
#
# ~\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py in _convert_listlike_datetimes(arg, box, format, name, tz, unit, errors, infer_datetime_format, dayfirst, yearfirst, exact)
#     259                 try:
#     260                     result, timezones = array_strptime(
# --> 261                         arg, format, exact=exact, errors=errors)
#     262                     if '%Z' in format or '%z' in format:
#     263                         return _return_parsed_timezone_results(
#
# pandas/_libs/tslibs/strptime.pyx in pandas._libs.tslibs.strptime.array_strptime()
#
# ValueError: time data '17/0719' does not match format '%d/%m/%y' (match)

# %% [markdown]
# Nos marco un error al tratar de convertir la variable fingreso a fecha. Al parecer, el problema tiene que ver con que hay un registro con una fecha inconsistente.

# %% [markdown]
# Filtraremos por la variable fingreso = 17/0719.

# %%
sql = "SELECT * FROM datos_format \
        WHERE fingreso = '17/0719'"
query = pandasql.sqldf(sql, globals())
query
# Out:
#    anio    mes  cve_hospital fingreso       autoref edocivil_descripcion  \
# 0  2019  Julio            12  17/0719  autoreferida          unión libre
#
#    edad desc_derechohab              nivel_edu    ocupacion  ... c_num  \
# 0    29       Gratuidad  preparatoria completa  Ama de Casa  ...   2.0
#
#                    motiles h_fingreso       desc_servicio  p_semgest  \
# 0  interrupción voluntaria       None  Gineco Obstetrícia        8.0
#
#    p_diasgesta p_consent       procile  s_complica  panticoncep
# 0         59.0        Si  Mifepristona          No          DIU
#
# [1 rows x 36 columns]

# %% [markdown]
# Podemos ver que la variable fingreso es la unica con incosistencias para este registro. Procederemos a corregirlo.

# %% [markdown]
# Empezaremos por obtener el indice del registro con la iconsistencia.

# %%
idx = datos_format.index[datos_format['fingreso'] == '17/0719']
idx = idx.values
idx = idx[0]
idx
# Out:
# 55608

# %% [markdown]
# Ahora corregiremos la observación. Cambiaremos 17/0719 por 17/07/19.

# %%
datos_format.at[idx, 'fingreso'] = '17/07/19'
datos_format.at[idx, 'fingreso']
# Out:
# '17/07/19'

# %% [markdown]
# Despues de corregir el error intentaremos cambiar el tipo a fecha de la variable fingreso.

# %%
datos_format['fingreso'] = pd.to_datetime(datos_format['fingreso'], format='%d/%m/%y')
datos_format['fingreso'].head()
# Out:
# 0   2016-01-12
# 1   2016-04-25
# 2   2018-07-11
# 3   2016-01-07
# 4          NaT
# Name: fingreso, dtype: datetime64[ns]

# %% [markdown]
# La variable fingreso ahora tiene el tipo correcto.

# %% [markdown]
# Seguiremos con la variable fmenstrua. Cambiaremos su tipo a fecha.

# %% [markdown]
# Haremos una consulta de los primeros registros unicos de la variable fmenstrua para ver que formato de fecha tiene.

# %%
sql = "SELECT DISTINCT fmenstrua FROM datos_format \
        LIMIT 5"
query = pandasql.sqldf(sql, globals())
query
# Out:
#   fmenstrua
# 0  16/11/15
# 1  25/02/16
# 2  18/05/18
# 3      None
# 4  26/11/15

# %% [markdown]
# El formato de la fecha tambien es %d/%m%/%y, utilizaremos la función de pandas para especificar el formato y cambiar la fecha.

# %%
datos_format['fmenstrua'] = pd.to_datetime(datos_format['fmenstrua'], format='%d/%m/%y')
datos_format['fmenstrua'].head()
# Out:
# 0   2015-11-16
# 1   2016-02-25
# 2   2018-05-18
# 3   2015-11-16
# 4          NaT
# Name: fmenstrua, dtype: datetime64[ns]

# %% [markdown]
# La variable fmenstrua ahora tiene el tipo correcto.

# %% [markdown]
# Por último, cambiaremos el tipo de la variable h_fingreso.

# %% [markdown]
# Haremos un conteo de los valores únicos de la variable h_fingreso para darnos una idea de que tipo de valores tenemos. Solo nos traeremos los 5 valores que tienen mayor frecuencia.

# %%
sql = "SELECT DISTINCT h_fingreso, count(*) FROM datos_format \
        GROUP BY h_fingreso \
        ORDER BY count(*) DESC\
        LIMIT 5"
query = pandasql.sqldf(sql, globals())
query
# Out:
#   h_fingreso  count(*)
# 0         NE     49140
# 1       None      7537
# 2   16/01/19        27
# 3   01/10/18        26
# 4   22/08/18        26

# %% [markdown]
# En el top tenemos el valor "NE", considerando que la variable debería de tener un formato de fecha, actualizaremos con el valor nulo para estos casos.

# %% [markdown]
# Encontraremos los indices de todos los registros con el valor "NE" y actualizaremos.

# %%
idx = datos_format.index[datos_format['h_fingreso'] == 'NE']
for i in idx:
    datos_format.at[i, 'h_fingreso'] = pd.NaT

# %% [markdown]
# Haremos el mismo conteo de la vez pasada.

# %%
sql = "SELECT DISTINCT h_fingreso, count(*) FROM datos_format \
        GROUP BY h_fingreso \
        ORDER BY count(*) DESC\
        LIMIT 5"
query = pandasql.sqldf(sql, globals())
query
# Out:
#   h_fingreso  count(*)
# 0       None     56677
# 1   16/01/19        27
# 2   01/10/18        26
# 3   22/08/18        26
# 4   15/05/19        25

# %% [markdown]
# Con la tabla de arriba validamos que ya no existen los valores "NE". Ahora intentaremos cambiar el tipo de la variable h_fingreso.

# %%
datos_format['h_fingreso'] = pd.to_datetime(datos_format['h_fingreso'], format='%d/%m/%y')
datos_format['h_fingreso'].head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py in _convert_listlike_datetimes(arg, box, format, name, tz, unit, errors, infer_datetime_format, dayfirst, yearfirst, exact)
#     290             try:
# --> 291                 values, tz = conversion.datetime_to_datetime64(arg)
#     292                 return DatetimeIndex._simple_new(values, name=name, tz=tz)
#
# pandas/_libs/tslibs/conversion.pyx in pandas._libs.tslibs.conversion.datetime_to_datetime64()
#
# TypeError: Unrecognized value type: <class 'str'>
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-58cac49e54f8> in <module>
# ----> 1 datos_format['h_fingreso'] = pd.to_datetime(datos_format['h_fingreso'], format='%d/%m/%y')
#       2 datos_format['h_fingreso'].head()
#
# ~\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py in to_datetime(arg, errors, dayfirst, yearfirst, utc, box, format, exact, unit, infer_datetime_format, origin, cache)
#     590         else:
#     591             from pandas import Series
# --> 592             values = convert_listlike(arg._values, True, format)
#     593             result = Series(values, index=arg.index, name=arg.name)
#     594     elif isinstance(arg, (ABCDataFrame, compat.MutableMapping)):
#
# ~\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py in _convert_listlike_datetimes(arg, box, format, name, tz, unit, errors, infer_datetime_format, dayfirst, yearfirst, exact)
#     292                 return DatetimeIndex._simple_new(values, name=name, tz=tz)
#     293             except (ValueError, TypeError):
# --> 294                 raise e
#     295
#     296     if result is None:
#
# ~\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py in _convert_listlike_datetimes(arg, box, format, name, tz, unit, errors, infer_datetime_format, dayfirst, yearfirst, exact)
#     259                 try:
#     260                     result, timezones = array_strptime(
# --> 261                         arg, format, exact=exact, errors=errors)
#     262                     if '%Z' in format or '%z' in format:
#     263                         return _return_parsed_timezone_results(
#
# pandas/_libs/tslibs/strptime.pyx in pandas._libs.tslibs.strptime.array_strptime()
#
# ValueError: time data '43521' does not match format '%d/%m/%y' (match)

# %% [markdown]
# La función nos marca un error, tenemos valores númericos para fechas (formato de Excel).

# %% [markdown]
# Cambiaremos el formato de estos valores con las funciones xldate_to_datetime() y to_datetime().

# %%
for i in range(0, len(datos_format)):
    try:
        datos_format.at[i, 'h_fingreso'] = pd.to_datetime(datos_format.at[i, 'h_fingreso'])
    except:
        if  datos_format.at[i, 'h_fingreso'] == None:
            continue
        else:
            datos_format.at[i, 'h_fingreso'] = pd.to_datetime(transform_data.xldate_to_datetime(int(datos_format.at[i, 'h_fingreso'])))

datos_format['h_fingreso'].head()
# Out:
# 0                    NaT
# 1    2016-04-25 00:00:00
# 2                    NaT
# 3                    NaT
# 4    2018-08-24 00:00:00
# Name: h_fingreso, dtype: object

# %% [markdown]
# Intentaremos una vez mas cambiar el tipo de la variable a fecha.

# %%
datos_format['h_fingreso'] = pd.to_datetime(datos_format['h_fingreso'], format='%d/%m/%y')
datos_format['h_fingreso'].head()
# Out:
# 0          NaT
# 1   2016-04-25
# 2          NaT
# 3          NaT
# 4   2018-08-24
# Name: h_fingreso, dtype: datetime64[ns]

# %% [markdown]
# Podemos ver que el tipo de la variable h_fingreso es de fecha.

# %% [markdown]
# Con esto terminamos de cambiar el tipo de las variables que presentaban incosistencias hasta ahora.

# %%
datos_format.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62003 entries, 0 to 62002
# Data columns (total 36 columns):
# anio                    62003 non-null int64
# mes                     62003 non-null object
# cve_hospital            62003 non-null int64
# fingreso                60420 non-null datetime64[ns]
# autoref                 16874 non-null object
# edocivil_descripcion    61887 non-null object
# edad                    62003 non-null int64
# desc_derechohab         54962 non-null object
# nivel_edu               60719 non-null object
# ocupacion               54282 non-null object
# religion                60183 non-null object
# parentesco              20163 non-null object
# entidad                 61983 non-null object
# alc_o_municipio         57910 non-null object
# menarca                 59114 non-null float64
# fsexual                 57750 non-null float64
# fmenstrua               55299 non-null datetime64[ns]
# sememb                  58403 non-null float64
# nhijos                  58794 non-null float64
# gesta                   59341 non-null float64
# naborto                 57888 non-null float64
# npartos                 58240 non-null float64
# ncesarea                57904 non-null float64
# nile                    49598 non-null float64
# consejeria              60047 non-null object
# anticonceptivo          55297 non-null object
# c_num                   41725 non-null float64
# motiles                 60915 non-null object
# h_fingreso              5326 non-null datetime64[ns]
# desc_servicio           57788 non-null object
# p_semgest               61974 non-null float64
# p_diasgesta             48602 non-null float64
# p_consent               17856 non-null object
# procile                 60290 non-null object
# s_complica              32768 non-null object
# panticoncep             45199 non-null object
# dtypes: datetime64[ns](3), float64(12), int64(3), object(18)
# memory usage: 17.0+ MB

# %% [markdown]
# Cambiaremos las letras mayusculas a minúsculas para cada obervación de las variables de tipo caracter.

# %%
datos_lower = transform_data.data_to_lowercase(datos_format)
datos_lower.head()
# Out:
#    anio     mes  cve_hospital   fingreso        autoref edocivil_descripcion  \
# 0  2016   enero            10 2016-01-12  autorreferida              soltera
# 1  2016   abril             1 2016-04-25             no          unión libre
# 2  2018   julio             4 2018-07-11            NaN              soltera
# 3  2016   enero            10 2016-01-07  autorreferida               casada
# 4  2018  agosto             7        NaT             no          unión libre
#
#    edad desc_derechohab              nivel_edu  \
# 0    34         ninguna      primaria completa
# 1    27         ninguna  licenciatura completa
# 2    29         ninguna    secundaria completa
# 3    33         ninguna  preparatoria completa
# 4    23             n/e  preparatoria completa
#
#                         ocupacion  ... c_num                  motiles  \
# 0                     desempleada  ...   2.0  interrupción voluntaria
# 1                          mesera  ...   NaN  interrupción voluntaria
# 2  trabajadora del sector público  ...   2.0  interrupción voluntaria
# 3                     ama de casa  ...   2.0  interrupción voluntaria
# 4                             NaN  ...   2.0  interrupción voluntaria
#
#   h_fingreso       desc_servicio  p_semgest  p_diasgesta p_consent  \
# 0        NaT  salud reproductiva        0.0          NaN        si
# 1 2016-04-25                 ile       11.0          2.0        si
# 2        NaT                 ile        7.0          6.0       NaN
# 3        NaT  salud reproductiva        4.0          NaN        si
# 4 2018-08-24  gineco obstetrícia        7.0          3.0       NaN
#
#                                      procile  s_complica          panticoncep
# 0                                misoprostol          si                  NaN
# 1                                 aspiración          no               condón
# 2  mifepristona 200 mg + misoprostol 800 mcg         NaN  anticonceptivo oral
# 3                                misoprostol          si                  NaN
# 4                                misoprostol         NaN  implante subdermico
#
# [5 rows x 36 columns]

# %% [markdown]
# Ahora nos aseguraremos de quitar los acentos de todas las columnas no numericas para cada observación.

# %%
datos_sin_acentos = transform_data.data_sin_acentos(datos_lower)
datos_sin_acentos.head()
# Out:
#    anio     mes  cve_hospital   fingreso        autoref edocivil_descripcion  \
# 0  2016   enero            10 2016-01-12  autorreferida              soltera
# 1  2016   abril             1 2016-04-25             no          union libre
# 2  2018   julio             4 2018-07-11            NaN              soltera
# 3  2016   enero            10 2016-01-07  autorreferida               casada
# 4  2018  agosto             7        NaT             no          union libre
#
#    edad desc_derechohab              nivel_edu  \
# 0    34         ninguna      primaria completa
# 1    27         ninguna  licenciatura completa
# 2    29         ninguna    secundaria completa
# 3    33         ninguna  preparatoria completa
# 4    23             n/e  preparatoria completa
#
#                         ocupacion  ... c_num                  motiles  \
# 0                     desempleada  ...   2.0  interrupcion voluntaria
# 1                          mesera  ...   NaN  interrupcion voluntaria
# 2  trabajadora del sector publico  ...   2.0  interrupcion voluntaria
# 3                     ama de casa  ...   2.0  interrupcion voluntaria
# 4                             NaN  ...   2.0  interrupcion voluntaria
#
#   h_fingreso       desc_servicio  p_semgest  p_diasgesta p_consent  \
# 0        NaT  salud reproductiva        0.0          NaN        si
# 1 2016-04-25                 ile       11.0          2.0        si
# 2        NaT                 ile        7.0          6.0       NaN
# 3        NaT  salud reproductiva        4.0          NaN        si
# 4 2018-08-24  gineco obstetricia        7.0          3.0       NaN
#
#                                      procile  s_complica          panticoncep
# 0                                misoprostol          si                  NaN
# 1                                 aspiracion          no               condon
# 2  mifepristona 200 mg + misoprostol 800 mcg         NaN  anticonceptivo oral
# 3                                misoprostol          si                  NaN
# 4                                misoprostol         NaN  implante subdermico
#
# [5 rows x 36 columns]

# %% [markdown]
# ## EDA y Data Profiling

# %%
datos_eda = datos_sin_acentos

# %%
datos_eda.shape
# Out:
# (62003, 36)

# %%
datos_eda.describe().transpose()
# Out:
#                 count         mean        std     min     25%     50%     75%  \
# anio          62003.0  2017.279519   1.038147  2016.0  2016.0  2017.0  2018.0
# cve_hospital  62003.0     4.957179   3.445688     1.0     2.0     4.0     7.0
# edad          62003.0    25.695450   6.280193    11.0    21.0    24.0    30.0
# menarca       59114.0    12.640018   1.753795     1.0    12.0    12.0    14.0
# fsexual       57750.0    16.978632   2.460949     0.0    15.0    17.0    18.0
# sememb        58403.0     7.439771   2.368694     0.0     6.0     7.0     9.0
# nhijos        58794.0     1.033966   1.141758     0.0     0.0     1.0     2.0
# gesta         59341.0     2.344922   1.455347     0.0     1.0     2.0     3.0
# naborto       57888.0     0.176306   0.471237     0.0     0.0     0.0     0.0
# npartos       58240.0     0.711624   1.066238     0.0     0.0     0.0     1.0
# ncesarea      57904.0     0.314935   0.600371     0.0     0.0     0.0     0.0
# nile          49598.0     0.173616   0.462694     0.0     0.0     0.0     0.0
# c_num         41725.0     1.683954   0.684814     0.0     1.0     2.0     2.0
# p_semgest     61974.0     6.842515   2.178380     0.0     5.0     7.0     8.0
# p_diasgesta   48602.0     5.179334  10.427514     0.0     2.0     3.0     5.0
#
#                  max
# anio          2019.0
# cve_hospital    14.0
# edad            53.0
# menarca         30.0
# fsexual         54.0
# sememb          50.0
# nhijos          10.0
# gesta           47.0
# naborto         10.0
# npartos         12.0
# ncesarea         7.0
# nile             9.0
# c_num           26.0
# p_semgest       12.0
# p_diasgesta     94.0

# %%
datos_eda.describe(include=['object']).transpose()
# Out:
#                       count unique                                        top  \
# mes                   62003     12                                      enero
# autoref               16874     33                              autorreferida
# edocivil_descripcion  61887      7                                    soltera
# desc_derechohab       54962     34                                    ninguna
# nivel_edu             60719     17                      preparatoria completa
# ocupacion             54282     53                                 estudiante
# religion              60183     13                                   catolica
# parentesco            20163     40                                      madre
# entidad               61983     32                           ciudad de mexico
# alc_o_municipio       57910    499                                 iztapalapa
# consejeria            60047      2                                         si
# anticonceptivo        55297     20                                    ninguno
# motiles               60915     13                    interrupcion voluntaria
# desc_servicio         57788      8                                        ile
# p_consent             17856      2                                         si
# procile               60290     20  mifepristona 200 mg + misoprostol 800 mcg
# s_complica            32768      2                                         no
# panticoncep           45199     44                        implante subdermico
#
#                        freq
# mes                    6201
# autoref               10887
# edocivil_descripcion  34423
# desc_derechohab       31771
# nivel_edu             27078
# ocupacion             15689
# religion              40295
# parentesco             4463
# entidad               39349
# alc_o_municipio        7776
# consejeria            59424
# anticonceptivo        32594
# motiles               60414
# desc_servicio         47760
# p_consent             17834
# procile               29075
# s_complica            29825
# panticoncep           13982

# %%
datos_eda.describe(include=['datetime64[ns]']).transpose()
# Out:
#             count unique                  top freq                first  \
# fingreso    60420    935  2016-09-28 00:00:00  128  2000-01-21 00:00:00
# fmenstrua   55299   1508  2017-11-15 00:00:00  118  1989-01-25 00:00:00
# h_fingreso   5326    574  2019-01-16 00:00:00   27  2006-07-21 00:00:00
#
#                            last
# fingreso    2048-04-30 00:00:00
# fmenstrua   2046-04-02 00:00:00
# h_fingreso  2019-12-07 00:00:00

# %%
datos_eda.head()
# Out:
#    anio     mes  cve_hospital   fingreso        autoref edocivil_descripcion  \
# 0  2016   enero            10 2016-01-12  autorreferida              soltera
# 1  2016   abril             1 2016-04-25             no          union libre
# 2  2018   julio             4 2018-07-11            NaN              soltera
# 3  2016   enero            10 2016-01-07  autorreferida               casada
# 4  2018  agosto             7        NaT             no          union libre
#
#    edad desc_derechohab              nivel_edu  \
# 0    34         ninguna      primaria completa
# 1    27         ninguna  licenciatura completa
# 2    29         ninguna    secundaria completa
# 3    33         ninguna  preparatoria completa
# 4    23             n/e  preparatoria completa
#
#                         ocupacion  ... c_num                  motiles  \
# 0                     desempleada  ...   2.0  interrupcion voluntaria
# 1                          mesera  ...   NaN  interrupcion voluntaria
# 2  trabajadora del sector publico  ...   2.0  interrupcion voluntaria
# 3                     ama de casa  ...   2.0  interrupcion voluntaria
# 4                             NaN  ...   2.0  interrupcion voluntaria
#
#   h_fingreso       desc_servicio  p_semgest  p_diasgesta p_consent  \
# 0        NaT  salud reproductiva        0.0          NaN        si
# 1 2016-04-25                 ile       11.0          2.0        si
# 2        NaT                 ile        7.0          6.0       NaN
# 3        NaT  salud reproductiva        4.0          NaN        si
# 4 2018-08-24  gineco obstetricia        7.0          3.0       NaN
#
#                                      procile  s_complica          panticoncep
# 0                                misoprostol          si                  NaN
# 1                                 aspiracion          no               condon
# 2  mifepristona 200 mg + misoprostol 800 mcg         NaN  anticonceptivo oral
# 3                                misoprostol          si                  NaN
# 4                                misoprostol         NaN  implante subdermico
#
# [5 rows x 36 columns]

# %%
datos_eda['anio_fingreso'] = pd.DatetimeIndex(datos_eda['fingreso']).year
datos_eda.head()
# Out:
#    anio     mes  cve_hospital   fingreso        autoref edocivil_descripcion  \
# 0  2016   enero            10 2016-01-12  autorreferida              soltera
# 1  2016   abril             1 2016-04-25             no          union libre
# 2  2018   julio             4 2018-07-11            NaN              soltera
# 3  2016   enero            10 2016-01-07  autorreferida               casada
# 4  2018  agosto             7        NaT             no          union libre
#
#    edad desc_derechohab              nivel_edu  \
# 0    34         ninguna      primaria completa
# 1    27         ninguna  licenciatura completa
# 2    29         ninguna    secundaria completa
# 3    33         ninguna  preparatoria completa
# 4    23             n/e  preparatoria completa
#
#                         ocupacion  ...                  motiles h_fingreso  \
# 0                     desempleada  ...  interrupcion voluntaria        NaT
# 1                          mesera  ...  interrupcion voluntaria 2016-04-25
# 2  trabajadora del sector publico  ...  interrupcion voluntaria        NaT
# 3                     ama de casa  ...  interrupcion voluntaria        NaT
# 4                             NaN  ...  interrupcion voluntaria 2018-08-24
#
#         desc_servicio p_semgest  p_diasgesta  p_consent  \
# 0  salud reproductiva       0.0          NaN         si
# 1                 ile      11.0          2.0         si
# 2                 ile       7.0          6.0        NaN
# 3  salud reproductiva       4.0          NaN         si
# 4  gineco obstetricia       7.0          3.0        NaN
#
#                                      procile  s_complica          panticoncep  \
# 0                                misoprostol          si                  NaN
# 1                                 aspiracion          no               condon
# 2  mifepristona 200 mg + misoprostol 800 mcg         NaN  anticonceptivo oral
# 3                                misoprostol          si                  NaN
# 4                                misoprostol         NaN  implante subdermico
#
#    anio_fingreso
# 0         2016.0
# 1         2016.0
# 2         2018.0
# 3         2016.0
# 4            NaN
#
# [5 rows x 37 columns]

# %%
datos_eda['mes_fingreso'] = pd.DatetimeIndex(datos_eda['fingreso']).month
datos_eda.head()
# Out:
#    anio     mes  cve_hospital   fingreso        autoref edocivil_descripcion  \
# 0  2016   enero            10 2016-01-12  autorreferida              soltera
# 1  2016   abril             1 2016-04-25             no          union libre
# 2  2018   julio             4 2018-07-11            NaN              soltera
# 3  2016   enero            10 2016-01-07  autorreferida               casada
# 4  2018  agosto             7        NaT             no          union libre
#
#    edad desc_derechohab              nivel_edu  \
# 0    34         ninguna      primaria completa
# 1    27         ninguna  licenciatura completa
# 2    29         ninguna    secundaria completa
# 3    33         ninguna  preparatoria completa
# 4    23             n/e  preparatoria completa
#
#                         ocupacion  ... h_fingreso       desc_servicio  \
# 0                     desempleada  ...        NaT  salud reproductiva
# 1                          mesera  ... 2016-04-25                 ile
# 2  trabajadora del sector publico  ...        NaT                 ile
# 3                     ama de casa  ...        NaT  salud reproductiva
# 4                             NaN  ... 2018-08-24  gineco obstetricia
#
#   p_semgest p_diasgesta  p_consent                                    procile  \
# 0       0.0         NaN         si                                misoprostol
# 1      11.0         2.0         si                                 aspiracion
# 2       7.0         6.0        NaN  mifepristona 200 mg + misoprostol 800 mcg
# 3       4.0         NaN         si                                misoprostol
# 4       7.0         3.0        NaN                                misoprostol
#
#   s_complica          panticoncep  anio_fingreso  mes_fingreso
# 0         si                  NaN         2016.0           1.0
# 1         no               condon         2016.0           4.0
# 2        NaN  anticonceptivo oral         2018.0           7.0
# 3         si                  NaN         2016.0           1.0
# 4        NaN  implante subdermico            NaN           NaN
#
# [5 rows x 38 columns]

# %%
datos_eda['mes'].unique()
# Out:
# array(['enero', 'abril', 'julio', 'agosto', 'mayo', 'febrero', 'junio',
#        'septiembre', 'marzo', 'octubre', 'noviembre', 'diciembre'],
#       dtype=object)

# %%
idx = datos_eda.columns.get_loc('mes_fingreso')

# %%
l = []
for i in range(0, len(datos_eda)):
    if datos_eda.iloc[i, idx] == 1:
        l.append('enero')
    elif datos_eda.iloc[i, idx] == 2:
        l.append('febrero')
    elif datos_eda.iloc[i, idx] == 3:
        l.append('marzo')
    elif datos_eda.iloc[i, idx] == 4:
        l.append('abril')
    elif datos_eda.iloc[i, idx] == 5:
        l.append('mayo')
    elif datos_eda.iloc[i, idx] == 6:
        l.append('junio')
    elif datos_eda.iloc[i, idx] == 7:
        l.append('julio')
    elif datos_eda.iloc[i, idx] == 8:
        l.append('agosto')
    elif datos_eda.iloc[i, idx] == 9:
        l.append('septiembre')
    elif datos_eda.iloc[i, idx] == 10:
        l.append('octubre')
    elif datos_eda.iloc[i, idx] == 11:
        l.append('noviembre')
    elif datos_eda.iloc[i, idx] == 12:
        l.append('diciembre')
    else:
        l.append(None)
        
new_var = np.array(l)

# %%
new_var
# Out:
# array(['enero', 'abril', 'julio', ..., 'julio', 'julio', 'julio'],
#       dtype=object)

# %%
datos_eda['mes_fingreso_ch'] = new_var

# %%
datos_eda.head()
# Out:
#    anio     mes  cve_hospital   fingreso        autoref edocivil_descripcion  \
# 0  2016   enero            10 2016-01-12  autorreferida              soltera
# 1  2016   abril             1 2016-04-25             no          union libre
# 2  2018   julio             4 2018-07-11            NaN              soltera
# 3  2016   enero            10 2016-01-07  autorreferida               casada
# 4  2018  agosto             7        NaT             no          union libre
#
#    edad desc_derechohab              nivel_edu  \
# 0    34         ninguna      primaria completa
# 1    27         ninguna  licenciatura completa
# 2    29         ninguna    secundaria completa
# 3    33         ninguna  preparatoria completa
# 4    23             n/e  preparatoria completa
#
#                         ocupacion  ...       desc_servicio p_semgest  \
# 0                     desempleada  ...  salud reproductiva       0.0
# 1                          mesera  ...                 ile      11.0
# 2  trabajadora del sector publico  ...                 ile       7.0
# 3                     ama de casa  ...  salud reproductiva       4.0
# 4                             NaN  ...  gineco obstetricia       7.0
#
#   p_diasgesta p_consent                                    procile  \
# 0         NaN        si                                misoprostol
# 1         2.0        si                                 aspiracion
# 2         6.0       NaN  mifepristona 200 mg + misoprostol 800 mcg
# 3         NaN        si                                misoprostol
# 4         3.0       NaN                                misoprostol
#
#    s_complica          panticoncep  anio_fingreso  mes_fingreso  \
# 0          si                  NaN         2016.0           1.0
# 1          no               condon         2016.0           4.0
# 2         NaN  anticonceptivo oral         2018.0           7.0
# 3          si                  NaN         2016.0           1.0
# 4         NaN  implante subdermico            NaN           NaN
#
#    mes_fingreso_ch
# 0            enero
# 1            abril
# 2            julio
# 3            enero
# 4             None
#
# [5 rows x 39 columns]

# %%
datos_eda['val_mes'] = datos_eda['mes'] == datos_eda['mes_fingreso_ch']

# %%
datos_eda['val_anio'] = datos_eda['anio'] == datos_eda['anio_fingreso']

# %%
datos_eda.head()
# Out:
#    anio     mes  cve_hospital   fingreso        autoref edocivil_descripcion  \
# 0  2016   enero            10 2016-01-12  autorreferida              soltera
# 1  2016   abril             1 2016-04-25             no          union libre
# 2  2018   julio             4 2018-07-11            NaN              soltera
# 3  2016   enero            10 2016-01-07  autorreferida               casada
# 4  2018  agosto             7        NaT             no          union libre
#
#    edad desc_derechohab              nivel_edu  \
# 0    34         ninguna      primaria completa
# 1    27         ninguna  licenciatura completa
# 2    29         ninguna    secundaria completa
# 3    33         ninguna  preparatoria completa
# 4    23             n/e  preparatoria completa
#
#                         ocupacion  ... p_diasgesta p_consent  \
# 0                     desempleada  ...         NaN        si
# 1                          mesera  ...         2.0        si
# 2  trabajadora del sector publico  ...         6.0       NaN
# 3                     ama de casa  ...         NaN        si
# 4                             NaN  ...         3.0       NaN
#
#                                      procile s_complica          panticoncep  \
# 0                                misoprostol         si                  NaN
# 1                                 aspiracion         no               condon
# 2  mifepristona 200 mg + misoprostol 800 mcg        NaN  anticonceptivo oral
# 3                                misoprostol         si                  NaN
# 4                                misoprostol        NaN  implante subdermico
#
#    anio_fingreso mes_fingreso  mes_fingreso_ch  val_mes  val_anio
# 0         2016.0          1.0            enero     True      True
# 1         2016.0          4.0            abril     True      True
# 2         2018.0          7.0            julio     True      True
# 3         2016.0          1.0            enero     True      True
# 4            NaN          NaN             None    False     False
#
# [5 rows x 41 columns]

# %%
datos_eda.describe(include=['bool']).transpose()
# Out:
#           count unique   top   freq
# val_mes   62003      2  True  60405
# val_anio  62003      2  True  60321

# %%
sql = "SELECT fingreso, count(*) FROM datos_eda \
        WHERE val_mes = 0 \
        GROUP BY fingreso \
        ORDER BY count(*) DESC \
        "
query = pandasql.sqldf(sql, globals())
query
# Out:
#                       fingreso  count(*)
# 0                         None      1583
# 1   2019-06-29 00:00:00.000000         3
# 2   2016-08-28 00:00:00.000000         2
# 3   2018-08-26 00:00:00.000000         2
# 4   2000-01-21 00:00:00.000000         1
# 5   2016-03-29 00:00:00.000000         1
# 6   2017-08-18 00:00:00.000000         1
# 7   2018-02-07 00:00:00.000000         1
# 8   2018-05-25 00:00:00.000000         1
# 9   2018-06-30 00:00:00.000000         1
# 10  2018-08-18 00:00:00.000000         1
# 11  2019-01-25 00:00:00.000000         1

# %%
q = datos_eda['fingreso'] == '2019-06-29'
datos_eda[q]
# Out:
#        anio    mes  cve_hospital   fingreso       autoref  \
# 55625  2019  julio            12 2019-06-29  autoreferida
# 55626  2019  julio            12 2019-06-29  autoreferida
# 58691  2019  julio            12 2019-06-29  autoreferida
#
#       edocivil_descripcion  edad desc_derechohab              nivel_edu  \
# 55625             separada    20            imss  licenciatura completa
# 55626          union libre    37            imss  licenciatura completa
# 58691              soltera    27       gratuidad  preparatoria completa
#
#          ocupacion  ... p_diasgesta p_consent      procile s_complica  \
# 55625   estudiante  ...        34.0        si  misoprostol         no
# 55626     empleada  ...        46.0        si  misoprostol         no
# 58691  comerciante  ...        69.0        si  misoprostol         no
#
#                panticoncep  anio_fingreso mes_fingreso  mes_fingreso_ch  \
# 55625                  NaN         2019.0          6.0            junio
# 55626  implante subdermico         2019.0          6.0            junio
# 58691                  diu         2019.0          6.0            junio
#
#        val_mes  val_anio
# 55625    False      True
# 55626    False      True
# 58691    False      True
#
# [3 rows x 41 columns]

# %%
q = datos_eda['fingreso'] == '2016-08-28'
datos_eda[q]
# Out:
#        anio      mes  cve_hospital   fingreso        autoref  \
# 1946   2016  octubre            12 2016-08-28  autorreferida
# 36707  2016  octubre            12 2016-08-28  autorreferida
#
#       edocivil_descripcion  edad desc_derechohab              nivel_edu  \
# 1946               soltera    22       gratuidad  preparatoria completa
# 36707              soltera    23       gratuidad  preparatoria completa
#
#         ocupacion  ... p_diasgesta p_consent                     procile  \
# 1946   estudiante  ...         NaN        si  mifepristona + misoprostol
# 36707  estudiante  ...         NaN        si  mifepristona + misoprostol
#
#       s_complica   panticoncep  anio_fingreso mes_fingreso  mes_fingreso_ch  \
# 1946          no  diu medicado         2016.0          8.0           agosto
# 36707         no  diu medicado         2016.0          8.0           agosto
#
#        val_mes  val_anio
# 1946     False      True
# 36707    False      True
#
# [2 rows x 41 columns]

# %%
q = datos_eda['fingreso'] == '2018-08-26'
datos_eda[q]
# Out:
#        anio    mes  cve_hospital   fingreso        autoref  \
# 1544   2018  junio            12 2018-08-26  autorreferida
# 34802  2018  junio            12 2018-08-26  autorreferida
#
#       edocivil_descripcion  edad desc_derechohab              nivel_edu  \
# 1544           union libre    27       gratuidad  preparatoria completa
# 34802          union libre    22       gratuidad    secundaria completa
#
#          ocupacion  ... p_diasgesta p_consent                     procile  \
# 1544   comerciante  ...        38.0        si  mifepristona + misoprostol
# 34802  ama de casa  ...        41.0        si  mifepristona + misoprostol
#
#       s_complica          panticoncep  anio_fingreso mes_fingreso  \
# 1544         NaN  implante subdermico         2018.0          8.0
# 34802        NaN                  NaN         2018.0          8.0
#
#        mes_fingreso_ch  val_mes  val_anio
# 1544            agosto    False      True
# 34802           agosto    False      True
#
# [2 rows x 41 columns]

# %%
q = datos_eda['fingreso'] == '2000-01-21'
datos_eda[q]
# Out:
#        anio    mes  cve_hospital   fingreso autoref edocivil_descripcion  \
# 36394  2017  marzo             3 2000-01-21     NaN              soltera
#
#        edad desc_derechohab              nivel_edu ocupacion  ... p_diasgesta  \
# 36394    23         ninguna  preparatoria completa    mesera  ...         NaN
#
#       p_consent                     procile s_complica  \
# 36394       NaN  mifepristona + misoprostol         no
#
#                         panticoncep  anio_fingreso mes_fingreso  \
# 36394  condon + implante subdermico         2000.0          1.0
#
#        mes_fingreso_ch  val_mes  val_anio
# 36394            enero    False     False
#
# [1 rows x 41 columns]

# %%
q = datos_eda['fingreso'] == '2016-03-29'
v = datos_eda['val_mes'] == 0
col = ['anio', 'mes', 'fingreso', 'fmenstrua', 'h_fingreso']
t = datos_eda[q & v]
t[col]
# Out:
#        anio    mes   fingreso  fmenstrua h_fingreso
# 34042  2016  junio 2016-03-29 2016-04-25        NaT

# %%
sql = "SELECT fingreso, count(*) FROM datos_eda \
        WHERE val_anio = 0 \
        GROUP BY fingreso \
        ORDER BY count(*) DESC \
        "
query = pandasql.sqldf(sql, globals())
query
# Out:
#                       fingreso  count(*)
# 0                         None      1583
# 1   2018-03-22 00:00:00.000000        26
# 2   2018-03-23 00:00:00.000000        20
# 3   2018-01-09 00:00:00.000000         6
# 4   2018-01-14 00:00:00.000000         6
# 5   2018-02-11 00:00:00.000000         6
# 6   2018-01-07 00:00:00.000000         5
# 7   2018-01-03 00:00:00.000000         4
# 8   2018-02-15 00:00:00.000000         4
# 9   2018-02-18 00:00:00.000000         4
# 10  2018-01-16 00:00:00.000000         3
# 11  2018-01-04 00:00:00.000000         2
# 12  2000-01-21 00:00:00.000000         1
# 13  2008-02-12 00:00:00.000000         1
# 14  2014-07-18 00:00:00.000000         1
# 15  2015-11-25 00:00:00.000000         1
# 16  2016-10-21 00:00:00.000000         1
# 17  2017-08-02 00:00:00.000000         1
# 18  2017-08-18 00:00:00.000000         1
# 19  2018-01-02 00:00:00.000000         1
# 20  2018-01-11 00:00:00.000000         1
# 21  2018-08-02 00:00:00.000000         1
# 22  2019-12-31 00:00:00.000000         1
# 23  2020-07-23 00:00:00.000000         1
# 24  2048-04-30 00:00:00.000000         1

# %%
q = datos_eda['fingreso'] == '2018-03-22'
v = datos_eda['val_anio'] == 0
col = ['anio', 'mes', 'fingreso', 'fmenstrua', 'h_fingreso']
t = datos_eda[q & v]
t[col]
# Out:
#        anio    mes   fingreso  fmenstrua h_fingreso
# 5456   2016  marzo 2018-03-22 2016-01-23        NaT
# 9069   2016  marzo 2018-03-22 2016-01-29        NaT
# 13286  2016  marzo 2018-03-22 2016-02-10        NaT
# 17819  2016  marzo 2018-03-22 2016-02-02        NaT
# 19671  2016  marzo 2018-03-22 2016-01-03        NaT
# 19672  2016  marzo 2018-03-22 2016-02-03        NaT
# 21219  2016  marzo 2018-03-22 2016-01-12        NaT
# 24899  2016  marzo 2018-03-22 2016-02-14        NaT
# 24900  2016  marzo 2018-03-22 2016-01-15        NaT
# 28732  2016  marzo 2018-03-22 2016-02-05        NaT
# 28739  2016  marzo 2018-03-22 2016-01-29        NaT
# 29941  2016  marzo 2018-03-22 2016-02-10        NaT
# 29942  2016  marzo 2018-03-22 2016-01-28        NaT
# 32344  2016  marzo 2018-03-22 2016-02-15        NaT
# 34689  2016  marzo 2018-03-22 2016-02-15        NaT
# 35462  2016  marzo 2018-03-22 2016-02-10        NaT
# 37511  2016  marzo 2018-03-22 2016-01-13        NaT
# 38166  2016  marzo 2018-03-22 2016-02-07        NaT
# 38517  2016  marzo 2018-03-22 2016-01-26        NaT
# 40509  2016  marzo 2018-03-22 2016-02-07        NaT
# 45001  2016  marzo 2018-03-22 2016-02-03        NaT
# 45012  2016  marzo 2018-03-22 2016-02-01        NaT
# 50480  2016  marzo 2018-03-22 2016-01-12        NaT
# 50481  2016  marzo 2018-03-22 2016-02-06        NaT
# 52622  2016  marzo 2018-03-22 2016-02-18        NaT
# 52623  2016  marzo 2018-03-22 2016-01-29        NaT

# %%
datos_eda.isna().sum()/datos_eda.shape[0] #Proporción de datos faltantes
# Out:
# anio                    0.000000
# mes                     0.000000
# cve_hospital            0.000000
# fingreso                0.025531
# autoref                 0.727852
# edocivil_descripcion    0.001871
# edad                    0.000000
# desc_derechohab         0.113559
# nivel_edu               0.020709
# ocupacion               0.124526
# religion                0.029353
# parentesco              0.674806
# entidad                 0.000323
# alc_o_municipio         0.066013
# menarca                 0.046595
# fsexual                 0.068593
# fmenstrua               0.108124
# sememb                  0.058062
# nhijos                  0.051756
# gesta                   0.042933
# naborto                 0.066368
# npartos                 0.060691
# ncesarea                0.066110
# nile                    0.200071
# consejeria              0.031547
# anticonceptivo          0.108156
# c_num                   0.327049
# motiles                 0.017548
# h_fingreso              0.914101
# desc_servicio           0.067981
# p_semgest               0.000468
# p_diasgesta             0.216135
# p_consent               0.712014
# procile                 0.027628
# s_complica              0.471509
# panticoncep             0.271019
# anio_fingreso           0.025531
# mes_fingreso            0.025531
# mes_fingreso_ch         0.025531
# val_mes                 0.000000
# val_anio                0.000000
# dtype: float64

# %% [markdown]
# Ya podemos observar que solo las variables año, mes, cve_hospital y edad no tienen observaciones faltantes.

# %%
datos_eda.dtypes
# Out:
# anio                             int64
# mes                             object
# cve_hospital                     int64
# fingreso                datetime64[ns]
# autoref                         object
# edocivil_descripcion            object
# edad                             int64
# desc_derechohab                 object
# nivel_edu                       object
# ocupacion                       object
# religion                        object
# parentesco                      object
# entidad                         object
# alc_o_municipio                 object
# menarca                        float64
# fsexual                        float64
# fmenstrua               datetime64[ns]
# sememb                         float64
# nhijos                         float64
# gesta                          float64
# naborto                        float64
# npartos                        float64
# ncesarea                       float64
# nile                           float64
# consejeria                      object
# anticonceptivo                  object
# c_num                          float64
# motiles                         object
# h_fingreso              datetime64[ns]
# desc_servicio                   object
# p_semgest                      float64
# p_diasgesta                    float64
# p_consent                       object
# procile                         object
# s_complica                      object
# panticoncep                     object
# anio_fingreso                  float64
# mes_fingreso                   float64
# mes_fingreso_ch                 object
# val_mes                           bool
# val_anio                          bool
# dtype: object

# %% [markdown]
# Vemos que todas ellas, salvo *anio* y *cve_hospital*, ya son de tipo object. Convirtamos éstas:

# %%
categoricas =  ["anio","cve_hospital"]
data_eda = transform_data.change_type(datos_eda,categoricas)
data_eda.dtypes
# Out:
# anio                            object
# mes                             object
# cve_hospital                    object
# fingreso                datetime64[ns]
# autoref                         object
# edocivil_descripcion            object
# edad                             int64
# desc_derechohab                 object
# nivel_edu                       object
# ocupacion                       object
# religion                        object
# parentesco                      object
# entidad                         object
# alc_o_municipio                 object
# menarca                        float64
# fsexual                        float64
# fmenstrua               datetime64[ns]
# sememb                         float64
# nhijos                         float64
# gesta                          float64
# naborto                        float64
# npartos                        float64
# ncesarea                       float64
# nile                           float64
# consejeria                      object
# anticonceptivo                  object
# c_num                          float64
# motiles                         object
# h_fingreso              datetime64[ns]
# desc_servicio                   object
# p_semgest                      float64
# p_diasgesta                    float64
# p_consent                       object
# procile                         object
# s_complica                      object
# panticoncep                     object
# anio_fingreso                  float64
# mes_fingreso                   float64
# mes_fingreso_ch                 object
# val_mes                           bool
# val_anio                          bool
# dtype: object

# %% [markdown]
# ### Variables categóricas

# %% [markdown]
# Nos centraremos ahora en las variables categóricas del data frame, mismas que seleccionamos con:

# %%
data_eda_cat = data_eda.select_dtypes(include=object)

# %% [markdown]
# Se trata de las siguientes columnas

# %%
data_eda_cat_columns = data_eda_cat.columns.values
data_eda_cat_columns
# Out:
# array(['anio', 'mes', 'cve_hospital', 'autoref', 'edocivil_descripcion',
#        'desc_derechohab', 'nivel_edu', 'ocupacion', 'religion',
#        'parentesco', 'entidad', 'alc_o_municipio', 'consejeria',
#        'anticonceptivo', 'motiles', 'desc_servicio', 'p_consent',
#        'procile', 's_complica', 'panticoncep', 'mes_fingreso_ch'],
#       dtype=object)

# %% [markdown]
# Para estas columnas queremos analizar lo siguiente:
# * Número de categorías
# * Valor de las categorías
# * Moda
# * Histograma
# * Valores faltantes
# * Número de observaciones con valores faltantes
# * Proporción de observaciones por categoría
# * ¿Hay faltas de ortografía?

# %% [markdown]
# **Número de categorías**
#
# Veamos ahora cuántos valores distintos contiene cada columna.

# %%
data_eda_cat.nunique()
# Out:
# anio                      4
# mes                      12
# cve_hospital             14
# autoref                  33
# edocivil_descripcion      7
# desc_derechohab          34
# nivel_edu                17
# ocupacion                53
# religion                 13
# parentesco               40
# entidad                  32
# alc_o_municipio         499
# consejeria                2
# anticonceptivo           20
# motiles                  13
# desc_servicio             8
# p_consent                 2
# procile                  20
# s_complica                2
# panticoncep              44
# mes_fingreso_ch          12
# dtype: int64

# %% [markdown]
# Vemos que algunas variables tienen un número bastante limitado de valores posibles, y que por su naturaleza bien pueden ser categóricas. Es el caso de *año, mes,cve_hospital,edocivil_descripcion, nivel_edu, religion, entidad, alc_o_municipio (?) , consejeria, anticonceptivo, desc_servicio, procile(?), s_complica* y *panticoncep(?)*.
#
# Veamos de qué tipo son actualmente:

# %% [markdown]
# **Valor de las categorías**

# %%
eda.categorias(data_eda)
# Out:
# Categorías para anio :  [2016 2018 2017 2019]
#
# Categorías para mes :  ['enero' 'abril' 'julio' 'agosto' 'mayo' 'febrero' 'junio' 'septiembre'
#  'marzo' 'octubre' 'noviembre' 'diciembre']
#
# Categorías para cve_hospital :  [10 1 4 7 9 11 2 13 12 5 6 3 14 8]
#
# Categorías para autoref :  ['autorreferida' 'no' nan 'no especificado' 'cst ii cultura maya'
#  'cst iii dr. david fragoso lizalde' 'chimalpa' 'cst mixcoac'
#  'cs san pedro jalpa' 'cst iii pedregal de las aguilas' 'palo alto'
#  'cst iii dr angel de la garza brito' 'cst iii cruz acalpixca' 'cst i dif'
#  'cst iii ampliacion hidalgo' 'cst iii lomas de la era' 'ticoman'
#  'cst iii jose castro villagrana' 'cs ajusco' 'cs tezozomoc'
#  'cs martinez baez' 'cst ii san bartolo ameyalco' 'cst iii el oasis'
#  'tlahuac' 'cst iii dr. gerardo varela mariscal' 'cst ii nayaritas'
#  'delegacion de tlalpan' 'cst i bekal' 'centro de salud' 'umm topilejo'
#  'cs mexico espania' 'cs santiago ahuizotla' 'cuajimalpa' 'autoreferida']
#
# Categorías para edocivil_descripcion :  ['soltera' 'union libre' 'casada' 'separada' 'n/e' 'divorciada' 'viuda'
#  nan]
#
# Categorías para desc_derechohab :  ['ninguna' 'n/e' 'gratuidad' 'imss' 'otro' 'seguro popular' 'issste'
#  'cuota' 'imss escolar' 'servicios estatales' 'gratuidad/imss'
#  'gratuidad/seguro popular' 'particular' 'gratuidad, pemex' 'issemym'
#  'otro/seguro popular' 'sedena' 'otro, issfam (militar)' 'pemex'
#  'seguro popular y gratuidad' 'pemex, seguro popular'
#  'imss, seguro popular' 'issfam' 'sedena/seguro popular'
#  'issste/gratuidad' 'imss/issste' 'gratuidad, sedena'
#  'gratuidad/seguro popular, servicios estatales'
#  'gratuidad, sedena, servicios estatales' 'naval' 'imss/issste/gratuidad'
#  'issste/sedena' 'exento' nan 'pago']
#
# Categorías para nivel_edu :  ['primaria completa' 'licenciatura completa' 'secundaria completa'
#  'preparatoria completa' 'ninguno' 'licenciatura incompleta'
#  'secundaria incompleta' 'maestria' 'no especifica' nan
#  'primaria incompleta' 'otra' 'preparatoria incompleta' 'preescolar'
#  'carrera tecnica' 'doctorado' 'posgrado' 'posgrado incompleto']
#
# Categorías para ocupacion :  ['desempleada' 'mesera' 'trabajadora del sector publico' 'ama de casa' nan
#  'estudiante' 'empleada' 'comerciante' 'dentista' 'obrera' 'estilista'
#  'cajera' 'policia o seguridad' 'cocinera' 'logistica o eventos'
#  'enfermera' 'trabajadora del hogar' 'fisioterapeuta'
#  'voluntaria o trabajadora social' 'trabajadora sexual' 'capturista'
#  'profesora o educadora' 'artista' 'telefonista' 'secretaria' 'ingeniera'
#  'chofer' 'constructura o elecetricista' 'abogada' 'ejecutiva'
#  'recepcionista' 'textil' 'fotografa' 'medico' 'asesora juridica'
#  'cientifica' 'psicologa' 'modelo' 'contadora' 'bibliotecaria'
#  'diseniadora' 'periodista o publicista' 'mecanica' 'vetarinaria'
#  'recursos humanos' 'arquitecta' 'informatica o tecnologia' 'nutiologa'
#  'auditora' 'constructora o elecetricista' 'administradora' 'paramedico'
#  'asesora financiera' 'trabajadora de campo']
#
# Categorías para religion :  ['ninguna' 'catolica' 'cristiana' nan 'creyente' 'mormon' 'otra'
#  'testigos de jeohva' 'evangelica' 'adventista del septimo dia'
#  'agnostica' 'budista' 'judia' 'protestante']
#
# Categorías para parentesco :  ['amiga' 'pareja' nan 'conyuge' 'madre' 'esposo' 'hermana' 'tia' 'padre'
#  'otro u otra' 'concubino' 'prima' 'suegra' 'hermano' 'hijo' 'amigo' 'tio'
#  'primo' 'novio' 'cuniada' 'hija' 'concubina' 'abuelo' 'sobrina'
#  'conocido' 'vecina' 'abuela' 'cuniado' 'conocida' 'ex pareja' 'vecino'
#  'familiar' 'esposa' 'yerno' 'sobrino' 'suegro' 'empleadora' 'padrastro'
#  'madrastra' 'otra u otro' 'responsable legal o tutor']
#
# Categorías para entidad :  ['estado de mexico' 'ciudad de mexico' 'baja california' 'nayarit'
#  'michoacan' 'morelos' 'oaxaca' 'zacatecas' 'puebla' 'veracruz' 'tlaxcala'
#  'durango' nan 'hidalgo' 'guanajuato' 'guerrero' 'sonora' 'queretaro'
#  'san luis potosi' 'jalisco' 'chihuahua' 'quintana roo' 'yucatan'
#  'sinaloa' 'aguascalientes' 'nuevo leon' 'tamaulipas' 'chiapas' 'coahuila'
#  'baja california sur' 'tabasco' 'colima' 'campeche']
#
# Categorías para alc_o_municipio :  [nan 'iztapalapa' 'nezahualcoyotl' 'coacalco' 'alvaro obregon'
#  'gustavo a madero' 'la paz' 'ecatepec de morelos' 'iztacalco'
#  'xochimilco' 'cuauhtemoc' 'tecamac' 'venustiano carranza' 'tlahuac'
#  'milpa alta' 'mighel hidalgo' 'valle de chalco' 'tlalnepantla de baz'
#  'tijuana' 'azcapotzalco' 'tultepec' 'huixquilucan' 'chalco'
#  'magdalena contreras' 'cuatitlan izcalli' 'san vicente' 'morelia'
#  'tlalpan' 'cuernavaca' 'san francisco' 'coyoacan' 'chicoloapan'
#  'chimalhuacan' 'fresnillo' 'puebla' 'acolman' 'tepotzotlan'
#  'la magdalena contreras' 'ixtapaluca' 'zumpango' 'xalapa' 'san pedro'
#  'benito juarez' 'carlos a carrillo' 'isidro fabela' 'amecameca' 'durango'
#  'tenango' 'tacambaro' 'tultitlan' 'san jose' 'mineral de la reforma'
#  'tepeyanco' 'celaya' 'acapulco de juarez' 'melchor ocampo' 'hermosillo'
#  'toluca' 'metepec' 'tequisquiapan' 'santiago' 'tonatico'
#  'cuajimalpa de morelos' 'tianguistenco' 'nicolas romero' 'lerma'
#  'texcoco' 'san felipe' 'chiconcuac' 'leon' 'tulancingo de bravo'
#  'santo tomas' 'ixtacuixtla de mariano matamoros' 'atizapan de zaragoza'
#  'puerto vallarta' 'tepic' 'tequixquiac' 'naucalpan de juarez' 'atenco'
#  'guadalajara' 'maravatio' 'chilpancingo' 'queretaro' 'juarez'
#  'chignahuapan' 'villa guerrero' 'progreso' 'solidaridad' 'hidalgo'
#  'tetela del volcan' 'ocoyoacac' 'coyotepec' 'chapa de mota'
#  'oaxaca de juarez' 'teoloyucan' 'jilotepec' 'yecapixtla' 'huauchinango'
#  'almoloya' 'banderilla' 'huehuetoca' 'zacatelco' 'jaltenco' 'zapopan'
#  'boca del rio' 'mineral del monte' 'tlalmanalco' 'merida'
#  'agua blanca de iturbide' 'nextlalpan' 'tlahuapan' 'actopan' 'culiacan'
#  'santa catarina' 'aguascalientes' 'el oro' 'ahuazotepec' 'monterrey'
#  'acajete' 'tonanitla' 'chihuahua' 'tezontepec de aldama' 'los reyes'
#  'san andres cholula' 'temixco' 'tepetitla de lardizabal' 'zinacantepec'
#  'pachuca' 'temascalcingo' 'izucar de matamoros' 'purisima del rincon'
#  'tizayuca' 'atlahuatla' 'tonala' 'teotihuacan' 'tampico' 'salvatierra'
#  'chinampac' 'tlajomulco de zuniiga' 'san salvador' 'cintalapa'
#  'santa lucia del camino' 'aculco' 'chalchicomula de sesma' 'jiutepec'
#  'villa hidalgo' 'apodaca' 'acatzingo' 'acatlan' 'ixcatepec' 'tehuacan'
#  'cuautla' 'tepetlaoxtoc' 'xonacatlan' 'huejotzingo' 'villa del carbon'
#  'donato guerra' 'chiautla' 'zempoala' 'tepeji del rio' 'yautepec'
#  'acambaro' 'el marques' 'tlalpujahua' 'villa de tezontepec' 'tenancingo'
#  'altamira' 'hueypoxtla' 'calnali' 'tula' 'zacapoaxtla' 'ixmiquilpan'
#  'zacatepec' 'ixtlahuaca' 'papalotla' 'zacatlan' 'ozumba' 'agua prieta'
#  'coronango' 'teloloapan' 'emiliano zapata' 'tapachula' 'apizaco'
#  'cholula' 'calpulalpan' 'saltillo' 'san miguel' 'tezoyuca' 'santa cruz'
#  'chiautempan' 'atlacomulco' 'amealco de bonfil' 'los cabos'
#  'tlahuelilpan' 'tlaxco' 'orizaba' 'cerritos' 'villa hermosa'
#  'gral escobedo' 'irapuato' 'tlaquepaque' 'amacuzac' 'huamantla'
#  'villa de alvarez' 'amanalco' 'jose sixto verduzco' 'chinconcuiac'
#  'zimapan' 'el salto' 'centro' 'otzolotepec' 'mexicali' 'coatzacoalcos'
#  'cocotitlan' 'panotla' 'san jeronimo' 'cardonal' 'salamanca'
#  'temascaltepec' 'calcahualco' 'jojutla' 'temantla' 'sultepec'
#  'atzacoalco' 'villa victoria' 'zacatecas' 'atotonilco' 'silao'
#  'tepetlixpa' 'san martin de las piramides' 'guadalupe' 'tlachichuca'
#  'huautla de jimenez' 'iguala' 'san blas' 'alvarado' 'capulhuac' 'temoaya'
#  'chichiquila' 'ciudad valles' 'pungarabato' 'juchitan' 'teolocholco'
#  'xicotepec' 'otumba' 'ixtapan' 'ayotla' 'atitalaquia' 'zumpahuacan'
#  'tecamachalco' 'playa vicente' 'santa maria' 'ixtacamaxtitlan'
#  'tangancicuaro' 'malinche' 'zapotitlan' 'coatepec' 'tepipan'
#  'ignacio de la llave' 'san cristobal' 'cancun' 'lagos de moreno'
#  'jilotzingo' 'juchitepec' 'apatzingan' 'jalpan' 'chiapas' 'manzanillo'
#  'atempan' 'atlixco' 'jonacatepec' 'jiquipilco' 'othon p blanco'
#  'san nicolas' 'coatlan del rio' 'ayapango' 'ocotlan' 'comalcalco'
#  'guanajuato' 'tarimbaro' 'san mateo' 'tetlatlahuca' 'villa de zaachila'
#  'torreon' 'cordoba' 'ahuacatlan' 'ayala' 'san luis'
#  'granjas valle de guadalupe' 'huasca de ocampo' 'tepeyualco'
#  'bahia de banderas' 'domingo arenas' 'calimaya' 'temascalapa' 'colima'
#  'san antonio la isla' 'soledad de graciano sanchez' 'apaxco'
#  'capultitlan' 'cortazar' 'san lorenzo axocomanitla' 'moroleon' 'cocula'
#  'huitzilac' 'acambay' 'atlazalpan' 'cozumel' 'la huacana' 'tecolutla'
#  'zacapu' 'sahuayo' '20 de noviembre' 'hueyotlipan' 'mazatlan' 'teziutlan'
#  'san isidro' 'mixquiahuala' 'nativitas' 'chapultepec'
#  'amatenango del valle' 'villa de allende' 'municipio libre'
#  'piedras negras' 'santa ana' 'xico' 'tejupilco' 'tuxpan' 'yanga'
#  'poza rica' 'mixtepec' 'matias romero avendanio'
#  'heroica ciudad de huajuapan de leon' 'citlaltepec' 'quiroga'
#  'tepeapulco' 'uruapan' 'dolores hidalgo' 'tizayucan' 'abasolo'
#  'chapulhuacan' 'tahmek' 's mateo atenco' 'alborada' 'san buena ventura'
#  'jesus maria' 'tlaltizapan' 'san lucas' 'altotonga' 'valle de bravo'
#  'san bartolo' 'san pablo' 'jerecuaro' 'jose joaquin de herrera'
#  'rafael lara grajales' 'xalatlaco' 'villa tejupam de la union' 'carmen'
#  'francisco i madero' 'huejutla de reyes' 'monclova' 'dos rios'
#  'mariano escobedo' 'zapotlan' 'matamoros' 'atoyac de alvarez'
#  'san agustin tlaxiaca' 'amaxac de guerrero' 'tuxtla gutierrez' 'fortin'
#  'amozoc' 'campeche' 'tolcayuca' 'ajuchitlan del progreso' 'el arenal'
#  'chenalho' 'coacoatzintla' 'zautla' 'lima' 'cusco' 'tepeapuloc'
#  'el mirador' 'patzcuaro' 'jerez' 'el mante' 'guachinango'
#  'chalcatongo de hidalgo' 'san andres tuxtla' 'colon' 'mecatlan' 'catorce'
#  'taxco de alarcon' 'chapingo' 'ocosingo' 'san rafael' 'buenavista'
#  'tecali de herrera' 'san marcos' 'ezequiel montes' 'real del monte'
#  'zitacuaro' 'cadereyta de montes' 'aporo' 'felipe carrillo puerto'
#  'loma xicotencatl' 'ixtenco' 'joquicingo' 'ojocaliente'
#  'soyaniquilpan de juarez' 'apetatitlan de antonio carvajal'
#  'huamuxtitlan' 'san julian' 'toliman' 'comonfort' 'ocampo' 'loreto'
#  'ensenada' 'zapotiltic' 'zacualpan' 'juan galindo' 'acoyacan' 'ajacuba'
#  'centla' 'atlangatepec' 'tecozautla' 'jantetelco' 'jolalpan'
#  'puente de ixtla' 'escobedo' 'la piedad' 'tlatlaya' 'romita'
#  'xochistlahuaca' 'aquixtla' 'frontera comalapa' 'puruandiro' 'el limon'
#  'martinez de la torre' 'playas de rosarito' 'ixtacalco'
#  'tepecoacuilco de trujano' 'axapusco' 'chilapa de alvarez' 'xalostoc'
#  'zamora' 'san esteban atatlahuca' 'yauhquemehcan' 'industrial san luis'
#  'cuautlalpan' 'juan c bonilla' 'chicontepec' 'ojuelos de jalisco'
#  'villa milpa alta' 'soltepec' 'molango de escamilla' 'alfajayucan'
#  'totolapan' 'tecomatlan' 'los heroes' 'huichapan' 'malinalco'
#  'acaxochitlan' 'rioverde' 'ahualulco' 'el paredon' 'zaragoza' 'misantla'
#  'cardenas' 'huehuetla' 'candelaria loxicha' 'tezozautla' 'chila'
#  'barrientos' 'poncitlan' 'alcozauca de guerrero' 'coatzintla' 'jaltocan'
#  'malinaltepec' 'calpan' 'chiautzingo' 'charapan' 'martir de cuilapan'
#  'alpoyeca' 'villa purificacion' 'iyotla' 'huejoculco' 'san sebastian'
#  'ecatzingo' 'loma bonita' 'playa del carmen' 'calvillo' 'valerio trujano'
#  'coxquihui' 'quimixtlan' 'molcaxac' 'huemanco' 'gustavo a. madero'
#  'zinapecuaro' 'zoquiapan' 'juan c. bonilla']
#
# Categorías para consejeria :  ['si' nan 'no']
#
# Categorías para anticonceptivo :  ['anticoncepcion de emergencia' 'condon' 'diu' 'ninguno' nan 'inyeccion'
#  'implante subdermico' 'barrera' 'hormonal oral' 'parche dermico'
#  'hormonal inyectable' 'pastillas anticonceptivas'
#  'anticoncepcion de emergencia y otro' 'vasectomia' 'condon y otro'
#  'coito interrumpido' 'calendario' 'anillo vaginal' 'medicamento'
#  'salpingoclacia' 'ritmo']
#
# Categorías para motiles :  ['interrupcion voluntaria' nan 'falta de recursos economicos'
#  'no lo desea en este momento'
#  'no quiere interrumpir sus estudios/trabajo'
#  'falla de metodo anticonceptivo' 'ya tiene muchos hijos'
#  'no especificado' 'motivos de salud' 'otro' 'problemas con la pareja'
#  'malformaciones' 'violacion' 'no tiene apoyo familiar']
#
# Categorías para desc_servicio :  ['salud reproductiva' 'ile' 'gineco obstetricia' nan 'consulta externa'
#  'enfermeria' 'cirugia ambulatoria' 'tococirugia' 'administracion']
#
# Categorías para p_consent :  ['si' nan 'no']
#
# Categorías para procile :  ['misoprostol' 'aspiracion' 'mifepristona 200 mg + misoprostol 800 mcg'
#  nan 'mifepristona + misoprostol' 'aeeu' 'ameu' 'medicamento' 'lui'
#  'aeeu + misoprostol' 'ameu + misoprostol'
#  'aeeu + 200 mcg mifepristona + 800 mcg misoprostol'
#  'aeeu + 400 mcg misoprostol' 'mifepristona' 'ameu + 800 mcg misoprostol'
#  'mifepristona 200 mg + misoprostol 800 mcg + misoprostol 400 mcg'
#  'medicamento + ameu' 'ameu + 200 mcg mifepristona + 800 mcg misoprostol'
#  'lui + 200 mcg misoprostol' 'ameu + 400 mcg misoprostol'
#  'aeeu + 800 mcg misoprostol']
#
# Categorías para s_complica :  ['si' 'no' nan]
#
# Categorías para panticoncep :  [nan 'condon' 'anticonceptivo oral' 'implante subdermico' 'ne'
#  'diu medicado'
#  'anticoncepcion de emergencia + condon + implante subdermico'
#  'condon + implante subdermico' 'condon + parches' 'parche'
#  'condon + diu medicado' 'ninguno' 'diu t de cobre'
#  'condon + diu t de cobre' 'diu' 'condon + otb' 'condon + diu' 'otro'
#  'condon + anticonceptivo oral' 'condon + inyeccion'
#  'condon + anticoncepcion de emergencia + parches'
#  'anticoncepcion de emergencia + condon' 'hormonal inyectable'
#  'anticoncepcion de emergencia' 'otb'
#  'anticoncepcion de emergencia + condon + diu medicado'
#  'diu medicado + implante subdermico'
#  'condon + implante subdermico + parches'
#  'condon + diu medicado + parches' 'implante subdermico + parches'
#  'anticoncepcion de emergencia + condon + diu t de cobre'
#  'anticoncepcion de emergencia + condon + inyeccion'
#  'condon + anticonceptivo oral + anticoncepcion de emergencia'
#  'condon + inyeccion + anticoncepcion de emergencia'
#  'diu medicado + diu t de cobre'
#  'condon + anticoncepcion de emergencia + parches + implante subdermico'
#  'condon + implante subdermico + inyeccion'
#  'anticoncepcion de emergencia + parches' 'anillo vaginal'
#  'anticoncepcion de emergencia + diu medicado + parches'
#  'condon + parches + anticonceptivo oral' 'inyeccion + parches'
#  'diu t de cobre + implante subdermico' 'diu t de cobre + parches'
#  'condon + anticonceptivo oral + implante subdermico']
#
# Categorías para mes_fingreso_ch :  ['enero' 'abril' 'julio' None 'agosto' 'mayo' 'febrero' 'junio'
#  'septiembre' 'marzo' 'octubre' 'noviembre' 'diciembre']

# %% [markdown]
# Notamos que hay una falta de ortografía en "testigos de jeohva", dentro de la columna "religion". Podemos corregirla en nuestro dataframe datos_eda.

# %%
data_eda.replace('testigos de jeohva', 'testigos de jehova',True)

# %% [markdown]
#  Verificamos que los valores se hayan actualizado

# %%
data_eda["religion"].unique()
# Out:
# array(['ninguna', 'catolica', 'cristiana', nan, 'creyente', 'mormon',
#        'otra', 'testigos de jehova', 'evangelica',
#        'adventista del septimo dia', 'agnostica', 'budista', 'judia',
#        'protestante'], dtype=object)

# %% [markdown]
# Además, podemos observar que hay varios valores capturados en lugar de nan, tal es el caso de:
#
#     * 'no especificado' en las columnas 'autoref', 'motiles'
#     * 'n/e' en las columnas 'edocivil_descripcion', 'desc_derechohab'
#     * 'no especifica' en la columna 'nivel_edu'
#
# Reemplacemos estos valores en

# %%
data_eda.replace(['no especificado','n/e','no especifica'], np.nan,True)

# %% [markdown]
# Volvemos a obtener las categorías:

# %%
eda.categorias(data_eda)
# Out:
# Categorías para mes :  ['enero' 'abril' 'julio' 'agosto' 'mayo' 'febrero' 'junio' 'septiembre'
#  'marzo' 'octubre' 'noviembre' 'diciembre']
#
# Categorías para autoref :  ['autorreferida' 'no' nan 'cst ii cultura maya'
#  'cst iii dr. david fragoso lizalde' 'chimalpa' 'cst mixcoac'
#  'cs san pedro jalpa' 'cst iii pedregal de las aguilas' 'palo alto'
#  'cst iii dr angel de la garza brito' 'cst iii cruz acalpixca' 'cst i dif'
#  'cst iii ampliacion hidalgo' 'cst iii lomas de la era' 'ticoman'
#  'cst iii jose castro villagrana' 'cs ajusco' 'cs tezozomoc'
#  'cs martinez baez' 'cst ii san bartolo ameyalco' 'cst iii el oasis'
#  'tlahuac' 'cst iii dr. gerardo varela mariscal' 'cst ii nayaritas'
#  'delegacion de tlalpan' 'cst i bekal' 'centro de salud' 'umm topilejo'
#  'cs mexico espania' 'cs santiago ahuizotla' 'cuajimalpa' 'autoreferida']
#
# Categorías para edocivil_descripcion :  ['soltera' 'union libre' 'casada' 'separada' nan 'divorciada' 'viuda']
#
# Categorías para desc_derechohab :  ['ninguna' nan 'gratuidad' 'imss' 'otro' 'seguro popular' 'issste' 'cuota'
#  'imss escolar' 'servicios estatales' 'gratuidad/imss'
#  'gratuidad/seguro popular' 'particular' 'gratuidad, pemex' 'issemym'
#  'otro/seguro popular' 'sedena' 'otro, issfam (militar)' 'pemex'
#  'seguro popular y gratuidad' 'pemex, seguro popular'
#  'imss, seguro popular' 'issfam' 'sedena/seguro popular'
#  'issste/gratuidad' 'imss/issste' 'gratuidad, sedena'
#  'gratuidad/seguro popular, servicios estatales'
#  'gratuidad, sedena, servicios estatales' 'naval' 'imss/issste/gratuidad'
#  'issste/sedena' 'exento' 'pago']
#
# Categorías para nivel_edu :  ['primaria completa' 'licenciatura completa' 'secundaria completa'
#  'preparatoria completa' 'ninguno' 'licenciatura incompleta'
#  'secundaria incompleta' 'maestria' nan 'primaria incompleta' 'otra'
#  'preparatoria incompleta' 'preescolar' 'carrera tecnica' 'doctorado'
#  'posgrado' 'posgrado incompleto']
#
# Categorías para ocupacion :  ['desempleada' 'mesera' 'trabajadora del sector publico' 'ama de casa' nan
#  'estudiante' 'empleada' 'comerciante' 'dentista' 'obrera' 'estilista'
#  'cajera' 'policia o seguridad' 'cocinera' 'logistica o eventos'
#  'enfermera' 'trabajadora del hogar' 'fisioterapeuta'
#  'voluntaria o trabajadora social' 'trabajadora sexual' 'capturista'
#  'profesora o educadora' 'artista' 'telefonista' 'secretaria' 'ingeniera'
#  'chofer' 'constructura o elecetricista' 'abogada' 'ejecutiva'
#  'recepcionista' 'textil' 'fotografa' 'medico' 'asesora juridica'
#  'cientifica' 'psicologa' 'modelo' 'contadora' 'bibliotecaria'
#  'diseniadora' 'periodista o publicista' 'mecanica' 'vetarinaria'
#  'recursos humanos' 'arquitecta' 'informatica o tecnologia' 'nutiologa'
#  'auditora' 'constructora o elecetricista' 'administradora' 'paramedico'
#  'asesora financiera' 'trabajadora de campo']
#
# Categorías para religion :  ['ninguna' 'catolica' 'cristiana' nan 'creyente' 'mormon' 'otra'
#  'testigos de jehova' 'evangelica' 'adventista del septimo dia'
#  'agnostica' 'budista' 'judia' 'protestante']
#
# Categorías para parentesco :  ['amiga' 'pareja' nan 'conyuge' 'madre' 'esposo' 'hermana' 'tia' 'padre'
#  'otro u otra' 'concubino' 'prima' 'suegra' 'hermano' 'hijo' 'amigo' 'tio'
#  'primo' 'novio' 'cuniada' 'hija' 'concubina' 'abuelo' 'sobrina'
#  'conocido' 'vecina' 'abuela' 'cuniado' 'conocida' 'ex pareja' 'vecino'
#  'familiar' 'esposa' 'yerno' 'sobrino' 'suegro' 'empleadora' 'padrastro'
#  'madrastra' 'otra u otro' 'responsable legal o tutor']
#
# Categorías para entidad :  ['estado de mexico' 'ciudad de mexico' 'baja california' 'nayarit'
#  'michoacan' 'morelos' 'oaxaca' 'zacatecas' 'puebla' 'veracruz' 'tlaxcala'
#  'durango' nan 'hidalgo' 'guanajuato' 'guerrero' 'sonora' 'queretaro'
#  'san luis potosi' 'jalisco' 'chihuahua' 'quintana roo' 'yucatan'
#  'sinaloa' 'aguascalientes' 'nuevo leon' 'tamaulipas' 'chiapas' 'coahuila'
#  'baja california sur' 'tabasco' 'colima' 'campeche']
#
# Categorías para alc_o_municipio :  [nan 'iztapalapa' 'nezahualcoyotl' 'coacalco' 'alvaro obregon'
#  'gustavo a madero' 'la paz' 'ecatepec de morelos' 'iztacalco'
#  'xochimilco' 'cuauhtemoc' 'tecamac' 'venustiano carranza' 'tlahuac'
#  'milpa alta' 'mighel hidalgo' 'valle de chalco' 'tlalnepantla de baz'
#  'tijuana' 'azcapotzalco' 'tultepec' 'huixquilucan' 'chalco'
#  'magdalena contreras' 'cuatitlan izcalli' 'san vicente' 'morelia'
#  'tlalpan' 'cuernavaca' 'san francisco' 'coyoacan' 'chicoloapan'
#  'chimalhuacan' 'fresnillo' 'puebla' 'acolman' 'tepotzotlan'
#  'la magdalena contreras' 'ixtapaluca' 'zumpango' 'xalapa' 'san pedro'
#  'benito juarez' 'carlos a carrillo' 'isidro fabela' 'amecameca' 'durango'
#  'tenango' 'tacambaro' 'tultitlan' 'san jose' 'mineral de la reforma'
#  'tepeyanco' 'celaya' 'acapulco de juarez' 'melchor ocampo' 'hermosillo'
#  'toluca' 'metepec' 'tequisquiapan' 'santiago' 'tonatico'
#  'cuajimalpa de morelos' 'tianguistenco' 'nicolas romero' 'lerma'
#  'texcoco' 'san felipe' 'chiconcuac' 'leon' 'tulancingo de bravo'
#  'santo tomas' 'ixtacuixtla de mariano matamoros' 'atizapan de zaragoza'
#  'puerto vallarta' 'tepic' 'tequixquiac' 'naucalpan de juarez' 'atenco'
#  'guadalajara' 'maravatio' 'chilpancingo' 'queretaro' 'juarez'
#  'chignahuapan' 'villa guerrero' 'progreso' 'solidaridad' 'hidalgo'
#  'tetela del volcan' 'ocoyoacac' 'coyotepec' 'chapa de mota'
#  'oaxaca de juarez' 'teoloyucan' 'jilotepec' 'yecapixtla' 'huauchinango'
#  'almoloya' 'banderilla' 'huehuetoca' 'zacatelco' 'jaltenco' 'zapopan'
#  'boca del rio' 'mineral del monte' 'tlalmanalco' 'merida'
#  'agua blanca de iturbide' 'nextlalpan' 'tlahuapan' 'actopan' 'culiacan'
#  'santa catarina' 'aguascalientes' 'el oro' 'ahuazotepec' 'monterrey'
#  'acajete' 'tonanitla' 'chihuahua' 'tezontepec de aldama' 'los reyes'
#  'san andres cholula' 'temixco' 'tepetitla de lardizabal' 'zinacantepec'
#  'pachuca' 'temascalcingo' 'izucar de matamoros' 'purisima del rincon'
#  'tizayuca' 'atlahuatla' 'tonala' 'teotihuacan' 'tampico' 'salvatierra'
#  'chinampac' 'tlajomulco de zuniiga' 'san salvador' 'cintalapa'
#  'santa lucia del camino' 'aculco' 'chalchicomula de sesma' 'jiutepec'
#  'villa hidalgo' 'apodaca' 'acatzingo' 'acatlan' 'ixcatepec' 'tehuacan'
#  'cuautla' 'tepetlaoxtoc' 'xonacatlan' 'huejotzingo' 'villa del carbon'
#  'donato guerra' 'chiautla' 'zempoala' 'tepeji del rio' 'yautepec'
#  'acambaro' 'el marques' 'tlalpujahua' 'villa de tezontepec' 'tenancingo'
#  'altamira' 'hueypoxtla' 'calnali' 'tula' 'zacapoaxtla' 'ixmiquilpan'
#  'zacatepec' 'ixtlahuaca' 'papalotla' 'zacatlan' 'ozumba' 'agua prieta'
#  'coronango' 'teloloapan' 'emiliano zapata' 'tapachula' 'apizaco'
#  'cholula' 'calpulalpan' 'saltillo' 'san miguel' 'tezoyuca' 'santa cruz'
#  'chiautempan' 'atlacomulco' 'amealco de bonfil' 'los cabos'
#  'tlahuelilpan' 'tlaxco' 'orizaba' 'cerritos' 'villa hermosa'
#  'gral escobedo' 'irapuato' 'tlaquepaque' 'amacuzac' 'huamantla'
#  'villa de alvarez' 'amanalco' 'jose sixto verduzco' 'chinconcuiac'
#  'zimapan' 'el salto' 'centro' 'otzolotepec' 'mexicali' 'coatzacoalcos'
#  'cocotitlan' 'panotla' 'san jeronimo' 'cardonal' 'salamanca'
#  'temascaltepec' 'calcahualco' 'jojutla' 'temantla' 'sultepec'
#  'atzacoalco' 'villa victoria' 'zacatecas' 'atotonilco' 'silao'
#  'tepetlixpa' 'san martin de las piramides' 'guadalupe' 'tlachichuca'
#  'huautla de jimenez' 'iguala' 'san blas' 'alvarado' 'capulhuac' 'temoaya'
#  'chichiquila' 'ciudad valles' 'pungarabato' 'juchitan' 'teolocholco'
#  'xicotepec' 'otumba' 'ixtapan' 'ayotla' 'atitalaquia' 'zumpahuacan'
#  'tecamachalco' 'playa vicente' 'santa maria' 'ixtacamaxtitlan'
#  'tangancicuaro' 'malinche' 'zapotitlan' 'coatepec' 'tepipan'
#  'ignacio de la llave' 'san cristobal' 'cancun' 'lagos de moreno'
#  'jilotzingo' 'juchitepec' 'apatzingan' 'jalpan' 'chiapas' 'manzanillo'
#  'atempan' 'atlixco' 'jonacatepec' 'jiquipilco' 'othon p blanco'
#  'san nicolas' 'coatlan del rio' 'ayapango' 'ocotlan' 'comalcalco'
#  'guanajuato' 'tarimbaro' 'san mateo' 'tetlatlahuca' 'villa de zaachila'
#  'torreon' 'cordoba' 'ahuacatlan' 'ayala' 'san luis'
#  'granjas valle de guadalupe' 'huasca de ocampo' 'tepeyualco'
#  'bahia de banderas' 'domingo arenas' 'calimaya' 'temascalapa' 'colima'
#  'san antonio la isla' 'soledad de graciano sanchez' 'apaxco'
#  'capultitlan' 'cortazar' 'san lorenzo axocomanitla' 'moroleon' 'cocula'
#  'huitzilac' 'acambay' 'atlazalpan' 'cozumel' 'la huacana' 'tecolutla'
#  'zacapu' 'sahuayo' '20 de noviembre' 'hueyotlipan' 'mazatlan' 'teziutlan'
#  'san isidro' 'mixquiahuala' 'nativitas' 'chapultepec'
#  'amatenango del valle' 'villa de allende' 'municipio libre'
#  'piedras negras' 'santa ana' 'xico' 'tejupilco' 'tuxpan' 'yanga'
#  'poza rica' 'mixtepec' 'matias romero avendanio'
#  'heroica ciudad de huajuapan de leon' 'citlaltepec' 'quiroga'
#  'tepeapulco' 'uruapan' 'dolores hidalgo' 'tizayucan' 'abasolo'
#  'chapulhuacan' 'tahmek' 's mateo atenco' 'alborada' 'san buena ventura'
#  'jesus maria' 'tlaltizapan' 'san lucas' 'altotonga' 'valle de bravo'
#  'san bartolo' 'san pablo' 'jerecuaro' 'jose joaquin de herrera'
#  'rafael lara grajales' 'xalatlaco' 'villa tejupam de la union' 'carmen'
#  'francisco i madero' 'huejutla de reyes' 'monclova' 'dos rios'
#  'mariano escobedo' 'zapotlan' 'matamoros' 'atoyac de alvarez'
#  'san agustin tlaxiaca' 'amaxac de guerrero' 'tuxtla gutierrez' 'fortin'
#  'amozoc' 'campeche' 'tolcayuca' 'ajuchitlan del progreso' 'el arenal'
#  'chenalho' 'coacoatzintla' 'zautla' 'lima' 'cusco' 'tepeapuloc'
#  'el mirador' 'patzcuaro' 'jerez' 'el mante' 'guachinango'
#  'chalcatongo de hidalgo' 'san andres tuxtla' 'colon' 'mecatlan' 'catorce'
#  'taxco de alarcon' 'chapingo' 'ocosingo' 'san rafael' 'buenavista'
#  'tecali de herrera' 'san marcos' 'ezequiel montes' 'real del monte'
#  'zitacuaro' 'cadereyta de montes' 'aporo' 'felipe carrillo puerto'
#  'loma xicotencatl' 'ixtenco' 'joquicingo' 'ojocaliente'
#  'soyaniquilpan de juarez' 'apetatitlan de antonio carvajal'
#  'huamuxtitlan' 'san julian' 'toliman' 'comonfort' 'ocampo' 'loreto'
#  'ensenada' 'zapotiltic' 'zacualpan' 'juan galindo' 'acoyacan' 'ajacuba'
#  'centla' 'atlangatepec' 'tecozautla' 'jantetelco' 'jolalpan'
#  'puente de ixtla' 'escobedo' 'la piedad' 'tlatlaya' 'romita'
#  'xochistlahuaca' 'aquixtla' 'frontera comalapa' 'puruandiro' 'el limon'
#  'martinez de la torre' 'playas de rosarito' 'ixtacalco'
#  'tepecoacuilco de trujano' 'axapusco' 'chilapa de alvarez' 'xalostoc'
#  'zamora' 'san esteban atatlahuca' 'yauhquemehcan' 'industrial san luis'
#  'cuautlalpan' 'juan c bonilla' 'chicontepec' 'ojuelos de jalisco'
#  'villa milpa alta' 'soltepec' 'molango de escamilla' 'alfajayucan'
#  'totolapan' 'tecomatlan' 'los heroes' 'huichapan' 'malinalco'
#  'acaxochitlan' 'rioverde' 'ahualulco' 'el paredon' 'zaragoza' 'misantla'
#  'cardenas' 'huehuetla' 'candelaria loxicha' 'tezozautla' 'chila'
#  'barrientos' 'poncitlan' 'alcozauca de guerrero' 'coatzintla' 'jaltocan'
#  'malinaltepec' 'calpan' 'chiautzingo' 'charapan' 'martir de cuilapan'
#  'alpoyeca' 'villa purificacion' 'iyotla' 'huejoculco' 'san sebastian'
#  'ecatzingo' 'loma bonita' 'playa del carmen' 'calvillo' 'valerio trujano'
#  'coxquihui' 'quimixtlan' 'molcaxac' 'huemanco' 'gustavo a. madero'
#  'zinapecuaro' 'zoquiapan' 'juan c. bonilla']
#
# Categorías para consejeria :  ['si' nan 'no']
#
# Categorías para anticonceptivo :  ['anticoncepcion de emergencia' 'condon' 'diu' 'ninguno' nan 'inyeccion'
#  'implante subdermico' 'barrera' 'hormonal oral' 'parche dermico'
#  'hormonal inyectable' 'pastillas anticonceptivas'
#  'anticoncepcion de emergencia y otro' 'vasectomia' 'condon y otro'
#  'coito interrumpido' 'calendario' 'anillo vaginal' 'medicamento'
#  'salpingoclacia' 'ritmo']
#
# Categorías para motiles :  ['interrupcion voluntaria' nan 'falta de recursos economicos'
#  'no lo desea en este momento'
#  'no quiere interrumpir sus estudios/trabajo'
#  'falla de metodo anticonceptivo' 'ya tiene muchos hijos'
#  'motivos de salud' 'otro' 'problemas con la pareja' 'malformaciones'
#  'violacion' 'no tiene apoyo familiar']
#
# Categorías para desc_servicio :  ['salud reproductiva' 'ile' 'gineco obstetricia' nan 'consulta externa'
#  'enfermeria' 'cirugia ambulatoria' 'tococirugia' 'administracion']
#
# Categorías para p_consent :  ['si' nan 'no']
#
# Categorías para procile :  ['misoprostol' 'aspiracion' 'mifepristona 200 mg + misoprostol 800 mcg'
#  nan 'mifepristona + misoprostol' 'aeeu' 'ameu' 'medicamento' 'lui'
#  'aeeu + misoprostol' 'ameu + misoprostol'
#  'aeeu + 200 mcg mifepristona + 800 mcg misoprostol'
#  'aeeu + 400 mcg misoprostol' 'mifepristona' 'ameu + 800 mcg misoprostol'
#  'mifepristona 200 mg + misoprostol 800 mcg + misoprostol 400 mcg'
#  'medicamento + ameu' 'ameu + 200 mcg mifepristona + 800 mcg misoprostol'
#  'lui + 200 mcg misoprostol' 'ameu + 400 mcg misoprostol'
#  'aeeu + 800 mcg misoprostol']
#
# Categorías para s_complica :  ['si' 'no' nan]
#
# Categorías para panticoncep :  [nan 'condon' 'anticonceptivo oral' 'implante subdermico' 'ne'
#  'diu medicado'
#  'anticoncepcion de emergencia + condon + implante subdermico'
#  'condon + implante subdermico' 'condon + parches' 'parche'
#  'condon + diu medicado' 'ninguno' 'diu t de cobre'
#  'condon + diu t de cobre' 'diu' 'condon + otb' 'condon + diu' 'otro'
#  'condon + anticonceptivo oral' 'condon + inyeccion'
#  'condon + anticoncepcion de emergencia + parches'
#  'anticoncepcion de emergencia + condon' 'hormonal inyectable'
#  'anticoncepcion de emergencia' 'otb'
#  'anticoncepcion de emergencia + condon + diu medicado'
#  'diu medicado + implante subdermico'
#  'condon + implante subdermico + parches'
#  'condon + diu medicado + parches' 'implante subdermico + parches'
#  'anticoncepcion de emergencia + condon + diu t de cobre'
#  'anticoncepcion de emergencia + condon + inyeccion'
#  'condon + anticonceptivo oral + anticoncepcion de emergencia'
#  'condon + inyeccion + anticoncepcion de emergencia'
#  'diu medicado + diu t de cobre'
#  'condon + anticoncepcion de emergencia + parches + implante subdermico'
#  'condon + implante subdermico + inyeccion'
#  'anticoncepcion de emergencia + parches' 'anillo vaginal'
#  'anticoncepcion de emergencia + diu medicado + parches'
#  'condon + parches + anticonceptivo oral' 'inyeccion + parches'
#  'diu t de cobre + implante subdermico' 'diu t de cobre + parches'
#  'condon + anticonceptivo oral + implante subdermico']
#
# Categorías para mes_fingreso_ch :  ['enero' 'abril' 'julio' None 'agosto' 'mayo' 'febrero' 'junio'
#  'septiembre' 'marzo' 'octubre' 'noviembre' 'diciembre']

# %% [markdown]
# **Moda**

# %%
data_eda_cat.mode().transpose()
# Out:
#                                                               0
# anio                                                       2016
# mes                                                       enero
# cve_hospital                                                  2
# autoref                                           autorreferida
# edocivil_descripcion                                    soltera
# desc_derechohab                                         ninguna
# nivel_edu                                 preparatoria completa
# ocupacion                                            estudiante
# religion                                               catolica
# parentesco                                                madre
# entidad                                        ciudad de mexico
# alc_o_municipio                                      iztapalapa
# consejeria                                                   si
# anticonceptivo                                          ninguno
# motiles                                 interrupcion voluntaria
# desc_servicio                                               ile
# p_consent                                                    si
# procile               mifepristona 200 mg + misoprostol 800 mcg
# s_complica                                                   no
# panticoncep                                 implante subdermico
# mes_fingreso_ch                                           enero

# %% [markdown]
# **Histograma**

# %% [markdown]
# **Valores faltantes**

# %% [markdown]
# **Número de observaciones con valores faltantes**

# %%
data_eda_cat.isna().sum()
# Out:
# anio                        0
# mes                         0
# cve_hospital                0
# autoref                 45129
# edocivil_descripcion      116
# desc_derechohab          7041
# nivel_edu                1284
# ocupacion                7721
# religion                 1820
# parentesco              41840
# entidad                    20
# alc_o_municipio          4093
# consejeria               1956
# anticonceptivo           6706
# motiles                  1088
# desc_servicio            4215
# p_consent               44147
# procile                  1713
# s_complica              29235
# panticoncep             16804
# mes_fingreso_ch          1583
# dtype: int64

# %% [markdown]
# **Proporción de observaciones por categoría**
#
# Veamos la proporción de datos faltantes en cada categoría

# %%
eda.proporcion_nas(data_eda_cat)
# Out:
# anio                    0.000000
# mes                     0.000000
# cve_hospital            0.000000
# autoref                 0.727852
# edocivil_descripcion    0.001871
# desc_derechohab         0.113559
# nivel_edu               0.020709
# ocupacion               0.124526
# religion                0.029353
# parentesco              0.674806
# entidad                 0.000323
# alc_o_municipio         0.066013
# consejeria              0.031547
# anticonceptivo          0.108156
# motiles                 0.017548
# desc_servicio           0.067981
# p_consent               0.712014
# procile                 0.027628
# s_complica              0.471509
# panticoncep             0.271019
# mes_fingreso_ch         0.025531
# dtype: float64

# %% [markdown]
# Podemos observar que la proporción de datos faltantes es notablemente elevada en las columnas *autoref* y *p_consent*

# %% [markdown]
# ### Variables numéricas

# %% [markdown]
# Nos centraremos ahora en las variables numéricas del data frame, mismas que seleccionamos con:

# %%
data_eda_num_columns = data_eda.select_dtypes(include=np.number).columns.values
data_eda_num_columns

# %% [markdown]
# Podemos observar que de acuerdo al diccionario de datos, todas estas columnas deben tomar únicamente valores enteros. Intentemos transformarlas a tipo *int*.

# %%
df = transform_data.change_type(data_eda,data_eda_num_columns, tipo ="int")

# %% [markdown]
# Vemos que obtenemos un error, ya que no podemos transformar a *int* las columnas que contienen NAs

# %%
#(~data_eda['edad'].astype(str).str.isdigit()).sum()

# %%
#(~(data_eda['menarca']).float.is_integer()).sum()

# %% [markdown]
# Queremos analizar lo siguiente:
# * Tipo de dato: float, integer
# * Número de observaciones
# * Mean
# * Desviación estándar
# * Cuartiles: 25%, 50%, 75%
# * Valor máximo
# * Valor mínimo
# * Número de observaciones únicos
# * Top 5 observaciones repetidas
# * Número de observaciones con valores faltantes
# * ¿Hay redondeos?

# %% [markdown]
# ### Feature selection & engineering

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.impute import SimpleImputer

# %% [markdown]
# Revisamos los datos faltantes:

# %%
datos_eda.isna().sum()

# %% [markdown]
# Haremos la imputaciones a los datos faltantes, usando la mediana:

# %%
datos_eda.dtypes

# %% [markdown]
# transformers = [('impute_consumo_total_mixto', SimpleImputer(strategy="median"), ['consumo_total_mixto']),
#                 ('impute_consumo_prom_dom', SimpleImputer(strategy="median"), ['consumo_prom_dom']),
#                 ('impute_consumo_total_dom', SimpleImputer(strategy="median"), ['consumo_total_dom']),
#                 ('impute_consumo_prom_mixto', SimpleImputer(strategy="median"), ['consumo_prom_mixto'])
#                ]
#
# col_trans = ColumnTransformer(transformers, remainder="drop", n_jobs=-1)
# col_trans.fit(datos_eda)

# %%
transformers = [('impute_consumo_total_mixto', SimpleImputer(strategy="median"), ['consumo_total_mixto']),
                ('impute_consumo_prom_dom', SimpleImputer(strategy="median"), ['consumo_prom_dom']),
               ('impute_consumo_total_dom', SimpleImputer(strategy="median"), ['consumo_total_dom']),
               ('impute_consumo_prom_mixto', SimpleImputer(strategy="median"), ['consumo_prom_mixto'])]

col_trans = ColumnTransformer(transformers, remainder="passthrough", n_jobs=-1, verbose=True)
col_trans.fit(df3)

u = col_trans.transform(df3)
u[0:5,]
#print(u[0:5,])
df4 = pd.DataFrame(u, 
             columns=['consumo_total_mixto','consumo_prom_dom', 'consumo_total_dom','consumo_prom_mixto','latitud','longitud','anio',  
       'alcaldia','consumo_total', 'consumo_prom','consumo_prom_no_dom', 'bimestre', 'consumo_total_no_dom', 'indice_des'])
df4.head()

# %%
X = datos_eda.consumo_total_mixto.values.reshape(datos_eda.shape[0],1)
